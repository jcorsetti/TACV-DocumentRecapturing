# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install torchinfo
# !pip install pytorch-lightning
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.7.1-py3-none-any.whl (22 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.7.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-1.8.5.post0-py3-none-any.whl (800 kB)
#      |████████████████████████████████| 800 kB 33.2 MB/s
# Collecting lightning-utilities!=0.4.0,>=0.3.0
#   Downloading lightning_utilities-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (4.4.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (6.0)
# Collecting tensorboardX>=2.2
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 76.3 MB/s
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (4.64.1)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (1.21.6)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (2022.11.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (21.3)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.0-py3-none-any.whl (512 kB)
#      |████████████████████████████████| 512 kB 76.8 MB/s
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (1.13.0+cu116)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.23.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=17.0->pytorch-lightning) (3.0.9)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorboardX>=2.2->pytorch-lightning) (3.19.6)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.8/dist-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2022.12.7)
# Installing collected packages: torchmetrics, tensorboardX, lightning-utilities, pytorch-lightning
# Successfully installed lightning-utilities-0.4.2 pytorch-lightning-1.8.5.post0 tensorboardX-2.5.1 torchmetrics-0.11.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.13.7-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 26.2 MB/s
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (3.19.6)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (2.3)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (7.1.2)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from wandb) (6.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (5.4.8)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 66.7 MB/s
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.12.0-py2.py3-none-any.whl (173 kB)
#      |████████████████████████████████| 173 kB 77.0 MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.15.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.8 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.11.1-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 66.2 MB/s
#   Downloading sentry_sdk-1.11.0-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 81.0 MB/s
#   Downloading sentry_sdk-1.10.1-py2.py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 90.0 MB/s
#   Downloading sentry_sdk-1.10.0-py2.py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 71.7 MB/s
#   Downloading sentry_sdk-1.9.10-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 74.3 MB/s
#   Downloading sentry_sdk-1.9.9-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 77.8 MB/s
#   Downloading sentry_sdk-1.9.8-py2.py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 80.2 MB/s
#   Downloading sentry_sdk-1.9.7-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 76.0 MB/s
#   Downloading sentry_sdk-1.9.6-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 73.5 MB/s
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 79.3 MB/s
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 75.1 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 84.2 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 79.1 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 82.7 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 85.3 MB/s
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=e55b5192d2d92c65862ff67a49e7305c90c294c796419e1f4776fa27bfbfc94d
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.29 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.9.0 setproctitle-1.3.2 shortuuid-1.0.11 smmap-5.0.0 wandb-0.13.7

# %%
# !cp -r 'gdrive/MyDrive/DLC2021' 'DLC2021'
# !cp -r 'gdrive/MyDrive/our_data' 'our_data'

# %%
# !unzip 'DLC2021/crops.zip' -d './DLC2021/'
# !unzip 'our_data/our_data.zip' -d './our_data/'
A
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./our_data/crops/6865.png
#   inflating: ./our_data/crops/6885.png
#   inflating: ./our_data/crops/6887.png
#   inflating: ./our_data/crops/6890.png
#   inflating: ./our_data/crops/6912.png
#   inflating: ./our_data/crops/6913.png
#   inflating: ./our_data/crops/6914.png
#   inflating: ./our_data/crops/6917.png
#   inflating: ./our_data/crops/6919.png
#   inflating: ./our_data/crops/6921.png
#   inflating: ./our_data/crops/6922.png
#   inflating: ./our_data/crops/6924.png
#   inflating: ./our_data/crops/6929.png
#   inflating: ./our_data/crops/6931.png
#   inflating: ./our_data/crops/6941.png
#   inflating: ./our_data/crops/6943.png
#   inflating: ./our_data/crops/6945.png
#   inflating: ./our_data/crops/6946.png
#   inflating: ./our_data/crops/6947.png
#   inflating: ./our_data/crops/6956.png
#   inflating: ./our_data/crops/6966.png
#   inflating: ./our_data/crops/6967.png
#   inflating: ./our_data/crops/6979.png
#   inflating: ./our_data/crops/6984.png
#   inflating: ./our_data/crops/6989.png
#   inflating: ./our_data/crops/6990.png
#   inflating: ./our_data/crops/6995.png
#   inflating: ./our_data/crops/6999.png
#   inflating: ./our_data/crops/7004.png
#   inflating: ./our_data/crops/7011.png
#   inflating: ./our_data/crops/7020.png
#   inflating: ./our_data/crops/7022.png
#   inflating: ./our_data/crops/7025.png
#   inflating: ./our_data/crops/7028.png
#   inflating: ./our_data/crops/7040.png
#   inflating: ./our_data/crops/7049.png
#   inflating: ./our_data/crops/7063.png
#   inflating: ./our_data/crops/7070.png
#   inflating: ./our_data/crops/7091.png
#   inflating: ./our_data/crops/7099.png
#   inflating: ./our_data/crops/7105.png
#   inflating: ./our_data/crops/7120.png
#   inflating: ./our_data/crops/7137.png
#   inflating: ./our_data/crops/7140.png
#   inflating: ./our_data/crops/7154.png
#   inflating: ./our_data/crops/7162.png
#   inflating: ./our_data/crops/7174.png
#   inflating: ./our_data/crops/7179.png
#   inflating: ./our_data/crops/7181.png
#   inflating: ./our_data/crops/7185.png
#   inflating: ./our_data/crops/7187.png
#   inflating: ./our_data/crops/7193.png
#   inflating: ./our_data/crops/7196.png
#   inflating: ./our_data/crops/7203.png
#   inflating: ./our_data/crops/7208.png
#   inflating: ./our_data/crops/7210.png
#   inflating: ./our_data/crops/7212.png
#   inflating: ./our_data/crops/7220.png
#   inflating: ./our_data/crops/7223.png
#   inflating: ./our_data/crops/7228.png
#   inflating: ./our_data/crops/7231.png
#   inflating: ./our_data/crops/7243.png
#   inflating: ./our_data/crops/7250.png
#   inflating: ./our_data/crops/7273.png
#   inflating: ./our_data/crops/7274.png
#   inflating: ./our_data/crops/7283.png
#   inflating: ./our_data/crops/7291.png
#   inflating: ./our_data/crops/7295.png
#   inflating: ./our_data/crops/7310.png
#   inflating: ./our_data/crops/7311.png
#   inflating: ./our_data/crops/7312.png
#   inflating: ./our_data/crops/7313.png
#   inflating: ./our_data/crops/7321.png
#   inflating: ./our_data/crops/7330.png
#   inflating: ./our_data/crops/7335.png
#   inflating: ./our_data/crops/7356.png
#   inflating: ./our_data/crops/7361.png
#   inflating: ./our_data/crops/7364.png
#   inflating: ./our_data/crops/7369.png
#   inflating: ./our_data/crops/7372.png
#   inflating: ./our_data/crops/7378.png
#   inflating: ./our_data/crops/7393.png
#   inflating: ./our_data/crops/7394.png
#   inflating: ./our_data/crops/7398.png
#   inflating: ./our_data/crops/7399.png
#   inflating: ./our_data/crops/7403.png
#   inflating: ./our_data/crops/7445.png
#   inflating: ./our_data/crops/7462.png
#   inflating: ./our_data/crops/7472.png
#   inflating: ./our_data/crops/7476.png
#   inflating: ./our_data/crops/7490.png
#   inflating: ./our_data/crops/7502.png
#   inflating: ./our_data/crops/7503.png
#   inflating: ./our_data/crops/7507.png
#   inflating: ./our_data/crops/7511.png
#   inflating: ./our_data/crops/7512.png
#   inflating: ./our_data/crops/7546.png
#   inflating: ./our_data/crops/7547.png
#   inflating: ./our_data/crops/7566.png
#   inflating: ./our_data/crops/7583.png
#   inflating: ./our_data/crops/7585.png
#   inflating: ./our_data/crops/7586.png
#   inflating: ./our_data/crops/7593.png
#   inflating: ./our_data/crops/7594.png
#   inflating: ./our_data/crops/7599.png
#   inflating: ./our_data/crops/7600.png
#   inflating: ./our_data/crops/7601.png
#   inflating: ./our_data/crops/7604.png
#   inflating: ./our_data/crops/7610.png
#   inflating: ./our_data/crops/7611.png
#   inflating: ./our_data/crops/7615.png
#   inflating: ./our_data/crops/7616.png
#   inflating: ./our_data/crops/7618.png
#   inflating: ./our_data/crops/7623.png
#   inflating: ./our_data/crops/7629.png
#   inflating: ./our_data/crops/7634.png
#   inflating: ./our_data/crops/7639.png
#   inflating: ./our_data/crops/7640.png
#   inflating: ./our_data/crops/7642.png
#   inflating: ./our_data/crops/7644.png
#   inflating: ./our_data/crops/7647.png
#   inflating: ./our_data/crops/7670.png
#   inflating: ./our_data/crops/7671.png
#   inflating: ./our_data/crops/7678.png
#   inflating: ./our_data/crops/7694.png
#   inflating: ./our_data/crops/7700.png
#   inflating: ./our_data/crops/7709.png
#   inflating: ./our_data/crops/7733.png
#   inflating: ./our_data/crops/7737.png
#   inflating: ./our_data/crops/7740.png
#   inflating: ./our_data/crops/7748.png
#   inflating: ./our_data/crops/7769.png
#   inflating: ./our_data/crops/7778.png
#   inflating: ./our_data/crops/7783.png
#   inflating: ./our_data/crops/7784.png
#   inflating: ./our_data/crops/7792.png
#   inflating: ./our_data/crops/7819.png
#   inflating: ./our_data/crops/7825.png
#   inflating: ./our_data/crops/7827.png
#   inflating: ./our_data/crops/7834.png
#   inflating: ./our_data/crops/7841.png
#   inflating: ./our_data/crops/2.png
#   inflating: ./our_data/crops/23.png
#   inflating: ./our_data/crops/27.png
#   inflating: ./our_data/crops/35.png
#   inflating: ./our_data/crops/51.png
#   inflating: ./our_data/crops/60.png
#   inflating: ./our_data/crops/65.png
#   inflating: ./our_data/crops/75.png
#   inflating: ./our_data/crops/90.png
#   inflating: ./our_data/crops/104.png
#   inflating: ./our_data/crops/111.png
#   inflating: ./our_data/crops/114.png
#   inflating: ./our_data/crops/116.png
#   inflating: ./our_data/crops/124.png
#   inflating: ./our_data/crops/129.png
#   inflating: ./our_data/crops/148.png
#   inflating: ./our_data/crops/150.png
#   inflating: ./our_data/crops/152.png
#   inflating: ./our_data/crops/155.png
#   inflating: ./our_data/crops/173.png
#   inflating: ./our_data/crops/175.png
#   inflating: ./our_data/crops/185.png
#   inflating: ./our_data/crops/194.png
#   inflating: ./our_data/crops/215.png
#   inflating: ./our_data/crops/225.png
#   inflating: ./our_data/crops/244.png
#   inflating: ./our_data/crops/254.png
#   inflating: ./our_data/crops/255.png
#   inflating: ./our_data/crops/270.png
#   inflating: ./our_data/crops/279.png
#   inflating: ./our_data/crops/283.png
#   inflating: ./our_data/crops/287.png
#   inflating: ./our_data/crops/297.png
#   inflating: ./our_data/crops/303.png
#   inflating: ./our_data/crops/311.png
#   inflating: ./our_data/crops/318.png
#   inflating: ./our_data/crops/319.png
#   inflating: ./our_data/crops/322.png
#   inflating: ./our_data/crops/327.png
#   inflating: ./our_data/crops/329.png
#   inflating: ./our_data/crops/333.png
#   inflating: ./our_data/crops/350.png
#   inflating: ./our_data/crops/352.png
#   inflating: ./our_data/crops/358.png
#   inflating: ./our_data/crops/359.png
#   inflating: ./our_data/crops/362.png
#   inflating: ./our_data/crops/377.png
#   inflating: ./our_data/crops/407.png
#   inflating: ./our_data/crops/419.png
#   inflating: ./our_data/crops/432.png
#   inflating: ./our_data/crops/439.png
#   inflating: ./our_data/crops/442.png
#   inflating: ./our_data/crops/444.png
#   inflating: ./our_data/crops/446.png
#   inflating: ./our_data/crops/460.png
#   inflating: ./our_data/crops/474.png
#   inflating: ./our_data/crops/476.png
#   inflating: ./our_data/crops/477.png
#   inflating: ./our_data/crops/484.png
#   inflating: ./our_data/crops/485.png
#   inflating: ./our_data/crops/500.png
#   inflating: ./our_data/crops/501.png
#   inflating: ./our_data/crops/503.png
#   inflating: ./our_data/crops/513.png
#   inflating: ./our_data/crops/536.png
#   inflating: ./our_data/crops/538.png
#   inflating: ./our_data/crops/541.png
#   inflating: ./our_data/crops/543.png
#   inflating: ./our_data/crops/548.png
#   inflating: ./our_data/crops/549.png
#   inflating: ./our_data/crops/550.png
#   inflating: ./our_data/crops/554.png
#   inflating: ./our_data/crops/567.png
#   inflating: ./our_data/crops/568.png
#   inflating: ./our_data/crops/581.png
#   inflating: ./our_data/crops/588.png
#   inflating: ./our_data/crops/607.png
#   inflating: ./our_data/crops/611.png
#   inflating: ./our_data/crops/616.png
#   inflating: ./our_data/crops/617.png
#   inflating: ./our_data/crops/624.png
#   inflating: ./our_data/crops/641.png
#   inflating: ./our_data/crops/649.png
#   inflating: ./our_data/crops/663.png
#   inflating: ./our_data/crops/668.png
#   inflating: ./our_data/crops/683.png
#   inflating: ./our_data/crops/688.png
#   inflating: ./our_data/crops/711.png
#   inflating: ./our_data/crops/720.png
#   inflating: ./our_data/crops/726.png
#   inflating: ./our_data/crops/731.png
#   inflating: ./our_data/crops/743.png
#   inflating: ./our_data/crops/744.png
#   inflating: ./our_data/crops/766.png
#   inflating: ./our_data/crops/777.png
#   inflating: ./our_data/crops/778.png
#   inflating: ./our_data/crops/787.png
#   inflating: ./our_data/crops/790.png
#   inflating: ./our_data/crops/798.png
#   inflating: ./our_data/crops/805.png
#   inflating: ./our_data/crops/814.png
#   inflating: ./our_data/crops/815.png
#   inflating: ./our_data/crops/820.png
#   inflating: ./our_data/crops/826.png
#   inflating: ./our_data/crops/827.png
#   inflating: ./our_data/crops/830.png
#   inflating: ./our_data/crops/833.png
#   inflating: ./our_data/crops/834.png
#   inflating: ./our_data/crops/837.png
#   inflating: ./our_data/crops/844.png
#   inflating: ./our_data/crops/859.png
#   inflating: ./our_data/crops/869.png
#   inflating: ./our_data/crops/878.png
#   inflating: ./our_data/crops/880.png
#   inflating: ./our_data/crops/891.png
#   inflating: ./our_data/crops/894.png
#   inflating: ./our_data/crops/905.png
#   inflating: ./our_data/crops/915.png
#   inflating: ./our_data/crops/920.png
#   inflating: ./our_data/crops/925.png
#   inflating: ./our_data/crops/926.png
#   inflating: ./our_data/crops/942.png
#   inflating: ./our_data/crops/951.png
#   inflating: ./our_data/crops/957.png
#   inflating: ./our_data/crops/998.png
#   inflating: ./our_data/crops/1010.png
#   inflating: ./our_data/crops/1013.png
#   inflating: ./our_data/crops/1020.png
#   inflating: ./our_data/crops/1027.png
#   inflating: ./our_data/crops/1040.png
#   inflating: ./our_data/crops/1045.png
#   inflating: ./our_data/crops/1046.png
#   inflating: ./our_data/crops/1050.png
#   inflating: ./our_data/crops/1064.png
#   inflating: ./our_data/crops/1067.png
#   inflating: ./our_data/crops/1069.png
#   inflating: ./our_data/crops/1073.png
#   inflating: ./our_data/crops/1076.png
#   inflating: ./our_data/crops/1079.png
#   inflating: ./our_data/crops/1080.png
#   inflating: ./our_data/crops/1100.png
#   inflating: ./our_data/crops/1104.png
#   inflating: ./our_data/crops/1116.png
#   inflating: ./our_data/crops/1118.png
#   inflating: ./our_data/crops/1125.png
#   inflating: ./our_data/crops/1139.png
#   inflating: ./our_data/crops/1140.png
#   inflating: ./our_data/crops/1149.png
#   inflating: ./our_data/crops/1150.png
#   inflating: ./our_data/crops/1167.png
#   inflating: ./our_data/crops/1179.png
#   inflating: ./our_data/crops/1180.png
#   inflating: ./our_data/crops/1181.png
#   inflating: ./our_data/crops/1188.png
#   inflating: ./our_data/crops/1212.png
#   inflating: ./our_data/crops/1222.png
#   inflating: ./our_data/crops/1232.png
#   inflating: ./our_data/crops/1233.png
#   inflating: ./our_data/crops/1234.png
#   inflating: ./our_data/crops/1260.png
#   inflating: ./our_data/crops/1261.png
#   inflating: ./our_data/crops/1274.png
#   inflating: ./our_data/crops/1283.png
#   inflating: ./our_data/crops/1286.png
#   inflating: ./our_data/crops/1300.png
#   inflating: ./our_data/crops/1301.png
#   inflating: ./our_data/crops/1313.png
#   inflating: ./our_data/crops/1315.png
#   inflating: ./our_data/crops/1325.png
#   inflating: ./our_data/crops/1339.png
#   inflating: ./our_data/crops/1344.png
#   inflating: ./our_data/crops/1345.png
#   inflating: ./our_data/crops/1348.png
#   inflating: ./our_data/crops/1351.png
#   inflating: ./our_data/crops/1353.png
#   inflating: ./our_data/crops/1354.png
#   inflating: ./our_data/crops/1367.png
#   inflating: ./our_data/crops/1382.png
#   inflating: ./our_data/crops/1383.png
#   inflating: ./our_data/crops/1385.png
#   inflating: ./our_data/crops/1393.png
#   inflating: ./our_data/crops/1400.png
#   inflating: ./our_data/crops/1404.png
#   inflating: ./our_data/crops/1409.png
#   inflating: ./our_data/crops/1410.png
#   inflating: ./our_data/crops/1417.png
#   inflating: ./our_data/crops/1420.png
#   inflating: ./our_data/crops/1421.png
#   inflating: ./our_data/crops/1429.png
#   inflating: ./our_data/crops/1435.png
#   inflating: ./our_data/crops/1443.png
#   inflating: ./our_data/crops/1446.png
#   inflating: ./our_data/crops/1453.png
#   inflating: ./our_data/crops/1460.png
#   inflating: ./our_data/crops/1463.png
#   inflating: ./our_data/crops/1466.png
#   inflating: ./our_data/crops/1467.png
#   inflating: ./our_data/crops/1476.png
#   inflating: ./our_data/crops/1483.png
#   inflating: ./our_data/crops/1500.png
#   inflating: ./our_data/crops/1507.png
#   inflating: ./our_data/crops/1513.png
#   inflating: ./our_data/crops/1514.png
#   inflating: ./our_data/crops/1516.png
#   inflating: ./our_data/crops/1537.png
#   inflating: ./our_data/crops/1551.png
#   inflating: ./our_data/crops/1554.png
#   inflating: ./our_data/crops/1564.png
#   inflating: ./our_data/crops/1576.png
#   inflating: ./our_data/crops/1584.png
#   inflating: ./our_data/crops/1591.png
#   inflating: ./our_data/crops/1593.png
#   inflating: ./our_data/crops/1595.png
#   inflating: ./our_data/crops/1598.png
#   inflating: ./our_data/crops/1599.png
#   inflating: ./our_data/crops/1603.png
#   inflating: ./our_data/crops/1606.png
#   inflating: ./our_data/crops/1613.png
#   inflating: ./our_data/crops/1616.png
#   inflating: ./our_data/crops/1620.png
#   inflating: ./our_data/crops/1627.png
#   inflating: ./our_data/crops/1629.png
#   inflating: ./our_data/crops/1631.png
#   inflating: ./our_data/crops/1636.png
#   inflating: ./our_data/crops/1641.png
#   inflating: ./our_data/crops/1655.png
#   inflating: ./our_data/crops/1659.png
#   inflating: ./our_data/crops/1663.png
#   inflating: ./our_data/crops/1664.png
#   inflating: ./our_data/crops/1685.png
#   inflating: ./our_data/crops/1686.png
#   inflating: ./our_data/crops/1687.png
#   inflating: ./our_data/crops/1694.png
#   inflating: ./our_data/crops/1719.png
#   inflating: ./our_data/crops/1720.png
#   inflating: ./our_data/crops/1734.png
#   inflating: ./our_data/crops/1751.png
#   inflating: ./our_data/crops/1758.png
#   inflating: ./our_data/crops/1759.png
#   inflating: ./our_data/crops/1762.png
#   inflating: ./our_data/crops/1764.png
#   inflating: ./our_data/crops/1772.png
#   inflating: ./our_data/crops/1780.png
#   inflating: ./our_data/crops/1797.png
#   inflating: ./our_data/crops/1808.png
#   inflating: ./our_data/crops/1817.png
#   inflating: ./our_data/crops/1829.png
#   inflating: ./our_data/crops/1835.png
#   inflating: ./our_data/crops/1837.png
#   inflating: ./our_data/crops/1861.png
#   inflating: ./our_data/crops/1878.png
#   inflating: ./our_data/crops/1886.png
#   inflating: ./our_data/crops/1888.png
#   inflating: ./our_data/crops/1891.png
#   inflating: ./our_data/crops/1899.png
#   inflating: ./our_data/crops/1900.png
#   inflating: ./our_data/crops/1911.png
#   inflating: ./our_data/crops/1933.png
#   inflating: ./our_data/crops/1938.png
#   inflating: ./our_data/crops/1943.png
#   inflating: ./our_data/crops/1956.png
#   inflating: ./our_data/crops/1958.png
#   inflating: ./our_data/crops/1960.png
#   inflating: ./our_data/crops/1972.png
#   inflating: ./our_data/crops/2001.png
#   inflating: ./our_data/crops/2004.png
#   inflating: ./our_data/crops/2016.png
#   inflating: ./our_data/crops/2017.png
#   inflating: ./our_data/crops/2018.png
#   inflating: ./our_data/crops/2020.png
#   inflating: ./our_data/crops/2028.png
#   inflating: ./our_data/crops/2041.png
#   inflating: ./our_data/crops/2047.png
#   inflating: ./our_data/crops/2049.png
#   inflating: ./our_data/crops/2056.png
#   inflating: ./our_data/crops/2075.png
#   inflating: ./our_data/crops/2080.png
#   inflating: ./our_data/crops/2086.png
#   inflating: ./our_data/crops/2090.png
#   inflating: ./our_data/crops/2094.png
#   inflating: ./our_data/crops/2100.png
#   inflating: ./our_data/crops/2103.png
#   inflating: ./our_data/crops/2109.png
#   inflating: ./our_data/crops/2112.png
#   inflating: ./our_data/crops/2115.png
#   inflating: ./our_data/crops/2122.png
#   inflating: ./our_data/crops/2139.png
#   inflating: ./our_data/crops/2141.png
#   inflating: ./our_data/crops/2145.png
#   inflating: ./our_data/crops/2146.png
#   inflating: ./our_data/crops/2165.png
#   inflating: ./our_data/crops/2171.png
#   inflating: ./our_data/crops/2173.png
#   inflating: ./our_data/crops/2174.png
#   inflating: ./our_data/crops/2183.png
#   inflating: ./our_data/crops/2195.png
#   inflating: ./our_data/crops/2202.png
#   inflating: ./our_data/crops/2203.png
#   inflating: ./our_data/crops/2208.png
#   inflating: ./our_data/crops/2209.png
#   inflating: ./our_data/crops/2215.png
#   inflating: ./our_data/crops/2222.png
#   inflating: ./our_data/crops/2226.png
#   inflating: ./our_data/crops/2238.png
#   inflating: ./our_data/crops/2251.png
#   inflating: ./our_data/crops/2259.png
#   inflating: ./our_data/crops/2261.png
#   inflating: ./our_data/crops/2265.png
#   inflating: ./our_data/crops/2274.png
#   inflating: ./our_data/crops/2285.png
#   inflating: ./our_data/crops/2317.png
#   inflating: ./our_data/crops/2319.png
#   inflating: ./our_data/crops/2334.png
#   inflating: ./our_data/crops/2336.png
#   inflating: ./our_data/crops/2339.png
#   inflating: ./our_data/crops/2343.png
#   inflating: ./our_data/crops/2346.png
#   inflating: ./our_data/crops/2374.png
#   inflating: ./our_data/crops/2375.png
#   inflating: ./our_data/crops/2378.png
#   inflating: ./our_data/crops/2384.png
#   inflating: ./our_data/crops/2396.png
#   inflating: ./our_data/crops/2397.png
#   inflating: ./our_data/crops/2407.png
#   inflating: ./our_data/crops/2416.png
#   inflating: ./our_data/crops/2424.png
#   inflating: ./our_data/crops/2426.png
#   inflating: ./our_data/crops/2430.png
#   inflating: ./our_data/crops/2445.png
#   inflating: ./our_data/crops/2450.png
#   inflating: ./our_data/crops/2453.png
#   inflating: ./our_data/crops/2455.png
#   inflating: ./our_data/crops/2456.png
#   inflating: ./our_data/crops/2463.png
#   inflating: ./our_data/crops/2470.png
#   inflating: ./our_data/crops/2483.png
#   inflating: ./our_data/crops/2484.png
#   inflating: ./our_data/crops/2497.png
#   inflating: ./our_data/crops/2501.png
#   inflating: ./our_data/crops/2527.png
#   inflating: ./our_data/crops/2532.png
#   inflating: ./our_data/crops/2540.png
#   inflating: ./our_data/crops/2546.png
#   inflating: ./our_data/crops/2549.png
#   inflating: ./our_data/crops/2557.png
#   inflating: ./our_data/crops/2573.png
#   inflating: ./our_data/crops/2584.png
#   inflating: ./our_data/crops/2587.png
#   inflating: ./our_data/crops/2593.png
#   inflating: ./our_data/crops/2600.png
#   inflating: ./our_data/crops/2601.png
#   inflating: ./our_data/crops/2606.png
#   inflating: ./our_data/crops/2614.png
#   inflating: ./our_data/crops/2618.png
#   inflating: ./our_data/crops/2619.png
#   inflating: ./our_data/crops/2623.png
#   inflating: ./our_data/crops/2638.png
#   inflating: ./our_data/crops/2641.png
#   inflating: ./our_data/crops/2657.png
#   inflating: ./our_data/crops/2664.png
#   inflating: ./our_data/crops/2670.png
#   inflating: ./our_data/crops/2673.png
#   inflating: ./our_data/crops/2678.png
#   inflating: ./our_data/crops/2681.png
#   inflating: ./our_data/crops/2682.png
#   inflating: ./our_data/crops/2683.png
#   inflating: ./our_data/crops/2689.png
#   inflating: ./our_data/crops/2695.png
#   inflating: ./our_data/crops/2704.png
#   inflating: ./our_data/crops/2706.png
#   inflating: ./our_data/crops/2708.png
#   inflating: ./our_data/crops/2712.png
#   inflating: ./our_data/crops/2718.png
#   inflating: ./our_data/crops/2719.png
#   inflating: ./our_data/crops/2764.png
#   inflating: ./our_data/crops/2765.png
#   inflating: ./our_data/crops/2780.png
#   inflating: ./our_data/crops/2781.png
#   inflating: ./our_data/crops/2805.png
#   inflating: ./our_data/crops/2816.png
#   inflating: ./our_data/crops/2822.png
#   inflating: ./our_data/crops/2827.png
#   inflating: ./our_data/crops/2828.png
#   inflating: ./our_data/crops/2830.png
#   inflating: ./our_data/crops/2832.png
#   inflating: ./our_data/crops/2839.png
#   inflating: ./our_data/crops/2847.png
#   inflating: ./our_data/crops/2862.png
#   inflating: ./our_data/crops/2867.png
#   inflating: ./our_data/crops/2884.png
#   inflating: ./our_data/crops/2900.png
#   inflating: ./our_data/crops/2908.png
#   inflating: ./our_data/crops/2920.png
#   inflating: ./our_data/crops/2922.png
#   inflating: ./our_data/crops/2948.png
#   inflating: ./our_data/crops/2949.png
#   inflating: ./our_data/crops/2956.png
#   inflating: ./our_data/crops/2965.png
#   inflating: ./our_data/crops/2969.png
#   inflating: ./our_data/crops/2984.png
#   inflating: ./our_data/crops/2987.png
#   inflating: ./our_data/crops/2997.png
#   inflating: ./our_data/crops/3000.png
#   inflating: ./our_data/crops/3002.png
#   inflating: ./our_data/crops/3005.png
#   inflating: ./our_data/crops/3009.png
#   inflating: ./our_data/crops/3011.png
#   inflating: ./our_data/crops/3031.png
#   inflating: ./our_data/crops/3056.png
#   inflating: ./our_data/crops/3058.png
#   inflating: ./our_data/crops/3062.png
#   inflating: ./our_data/crops/3068.png
#   inflating: ./our_data/crops/3113.png
#   inflating: ./our_data/crops/3135.png
#   inflating: ./our_data/crops/3136.png
#   inflating: ./our_data/crops/3138.png
#   inflating: ./our_data/crops/3146.png
#   inflating: ./our_data/crops/3156.png
#   inflating: ./our_data/crops/3165.png
#   inflating: ./our_data/crops/3167.png
#   inflating: ./our_data/crops/3168.png
#   inflating: ./our_data/crops/3194.png
#   inflating: ./our_data/crops/3215.png
#   inflating: ./our_data/crops/3223.png
#   inflating: ./our_data/crops/3224.png
#   inflating: ./our_data/crops/3230.png
#   inflating: ./our_data/crops/3243.png
#   inflating: ./our_data/crops/3255.png
#   inflating: ./our_data/crops/3267.png
#   inflating: ./our_data/crops/3275.png
#   inflating: ./our_data/crops/3276.png
#   inflating: ./our_data/crops/3291.png
#   inflating: ./our_data/crops/3293.png
#   inflating: ./our_data/crops/3315.png
#   inflating: ./our_data/crops/3322.png
#   inflating: ./our_data/crops/3332.png
#   inflating: ./our_data/crops/3333.png
#   inflating: ./our_data/crops/3336.png
#   inflating: ./our_data/crops/3355.png
#   inflating: ./our_data/crops/3356.png
#   inflating: ./our_data/crops/3386.png
#   inflating: ./our_data/crops/3388.png
#   inflating: ./our_data/crops/3395.png
#   inflating: ./our_data/crops/3415.png
#   inflating: ./our_data/crops/3420.png
#   inflating: ./our_data/crops/3433.png
#   inflating: ./our_data/crops/3442.png
#   inflating: ./our_data/crops/3462.png
#   inflating: ./our_data/crops/3464.png
#   inflating: ./our_data/crops/3465.png
#   inflating: ./our_data/crops/3472.png
#   inflating: ./our_data/crops/3480.png
#   inflating: ./our_data/crops/3503.png
#   inflating: ./our_data/crops/3521.png
#   inflating: ./our_data/crops/3524.png
#   inflating: ./our_data/crops/3532.png
#   inflating: ./our_data/crops/3533.png
#   inflating: ./our_data/crops/3545.png
#   inflating: ./our_data/crops/3551.png
#   inflating: ./our_data/crops/3552.png
#   inflating: ./our_data/crops/3555.png
#   inflating: ./our_data/crops/3557.png
#   inflating: ./our_data/crops/3567.png
#   inflating: ./our_data/crops/3573.png
#   inflating: ./our_data/crops/3577.png
#   inflating: ./our_data/crops/3578.png
#   inflating: ./our_data/crops/3579.png
#   inflating: ./our_data/crops/3582.png
#   inflating: ./our_data/crops/3583.png
#   inflating: ./our_data/crops/3585.png
#   inflating: ./our_data/crops/3602.png
#   inflating: ./our_data/crops/3605.png
#   inflating: ./our_data/crops/3609.png
#   inflating: ./our_data/crops/3616.png
#   inflating: ./our_data/crops/3632.png
#   inflating: ./our_data/crops/3634.png
#   inflating: ./our_data/crops/3642.png
#   inflating: ./our_data/crops/3648.png
#   inflating: ./our_data/crops/3649.png
#   inflating: ./our_data/crops/3654.png
#   inflating: ./our_data/crops/3662.png
#   inflating: ./our_data/crops/3672.png
#   inflating: ./our_data/crops/3684.png
#   inflating: ./our_data/crops/3685.png
#   inflating: ./our_data/crops/3714.png
#   inflating: ./our_data/crops/3723.png
#   inflating: ./our_data/crops/3727.png
#   inflating: ./our_data/crops/3737.png
#   inflating: ./our_data/crops/3744.png
#   inflating: ./our_data/crops/3745.png
#   inflating: ./our_data/crops/3747.png
#   inflating: ./our_data/crops/3762.png
#   inflating: ./our_data/crops/3768.png
#   inflating: ./our_data/crops/3776.png
#   inflating: ./our_data/crops/3781.png
#   inflating: ./our_data/crops/3794.png
#   inflating: ./our_data/crops/3798.png
#   inflating: ./our_data/crops/3800.png
#   inflating: ./our_data/crops/3802.png
#   inflating: ./our_data/crops/3810.png
#   inflating: ./our_data/crops/3817.png
#   inflating: ./our_data/crops/3818.png
#   inflating: ./our_data/crops/3834.png
#   inflating: ./our_data/crops/3863.png
#   inflating: ./our_data/crops/3870.png
#   inflating: ./our_data/crops/3879.png
#   inflating: ./our_data/crops/3881.png
#   inflating: ./our_data/crops/3894.png
#   inflating: ./our_data/crops/3900.png
#   inflating: ./our_data/crops/3902.png
#   inflating: ./our_data/crops/3904.png
#   inflating: ./our_data/crops/3906.png
#   inflating: ./our_data/crops/3907.png
#   inflating: ./our_data/crops/3912.png
#   inflating: ./our_data/crops/3915.png
#   inflating: ./our_data/crops/3917.png
#   inflating: ./our_data/crops/3920.png
#   inflating: ./our_data/crops/3922.png
#   inflating: ./our_data/crops/3941.png
#   inflating: ./our_data/crops/3948.png
#   inflating: ./our_data/crops/3949.png
#   inflating: ./our_data/crops/3951.png
#   inflating: ./our_data/crops/3960.png
#   inflating: ./our_data/crops/3965.png
#   inflating: ./our_data/crops/3970.png
#   inflating: ./our_data/crops/3975.png
#   inflating: ./our_data/crops/3976.png
#   inflating: ./our_data/crops/3983.png
#   inflating: ./our_data/crops/3988.png
#   inflating: ./our_data/crops/3999.png
#   inflating: ./our_data/crops/4007.png
#   inflating: ./our_data/crops/4012.png
#   inflating: ./our_data/crops/4015.png
#   inflating: ./our_data/crops/4018.png
#   inflating: ./our_data/crops/4036.png
#   inflating: ./our_data/crops/4040.png
#   inflating: ./our_data/crops/4058.png
#   inflating: ./our_data/crops/4068.png
#   inflating: ./our_data/crops/4084.png
#   inflating: ./our_data/crops/4101.png
#   inflating: ./our_data/crops/4104.png
#   inflating: ./our_data/crops/4110.png
#   inflating: ./our_data/crops/4117.png
#   inflating: ./our_data/crops/4121.png
#   inflating: ./our_data/crops/4122.png
#   inflating: ./our_data/crops/4133.png
#   inflating: ./our_data/crops/4141.png
#   inflating: ./our_data/crops/4146.png
#   inflating: ./our_data/crops/4150.png
#   inflating: ./our_data/crops/4153.png
#   inflating: ./our_data/crops/4155.png
#   inflating: ./our_data/crops/4164.png
#   inflating: ./our_data/crops/4183.png
#   inflating: ./our_data/crops/4184.png
#   inflating: ./our_data/crops/4185.png
#   inflating: ./our_data/crops/4188.png
#   inflating: ./our_data/crops/4191.png
#   inflating: ./our_data/crops/4192.png
#   inflating: ./our_data/crops/4195.png
#   inflating: ./our_data/crops/4197.png
#   inflating: ./our_data/crops/4213.png
#   inflating: ./our_data/crops/4222.png
#   inflating: ./our_data/crops/4227.png
#   inflating: ./our_data/crops/4228.png
#   inflating: ./our_data/crops/4250.png
#   inflating: ./our_data/crops/4251.png
#   inflating: ./our_data/crops/4252.png
#   inflating: ./our_data/crops/4271.png
#   inflating: ./our_data/crops/4275.png
#   inflating: ./our_data/crops/4284.png
#   inflating: ./our_data/crops/4298.png
#   inflating: ./our_data/crops/4299.png
#   inflating: ./our_data/crops/4305.png
#   inflating: ./our_data/crops/4317.png
#   inflating: ./our_data/crops/4320.png
#   inflating: ./our_data/crops/4329.png
#   inflating: ./our_data/crops/4339.png
#   inflating: ./our_data/crops/4348.png
#   inflating: ./our_data/crops/4349.png
#   inflating: ./our_data/crops/4367.png
#   inflating: ./our_data/crops/4374.png
#   inflating: ./our_data/crops/4398.png
#   inflating: ./our_data/crops/4406.png
#   inflating: ./our_data/crops/4424.png
#   inflating: ./our_data/crops/4428.png
#   inflating: ./our_data/crops/4432.png
#   inflating: ./our_data/crops/4433.png
#   inflating: ./our_data/crops/4441.png
#   inflating: ./our_data/crops/4462.png
#   inflating: ./our_data/crops/4464.png
#   inflating: ./our_data/crops/4478.png
#   inflating: ./our_data/crops/4484.png
#   inflating: ./our_data/crops/4497.png
#   inflating: ./our_data/crops/4500.png
#   inflating: ./our_data/crops/4514.png
#   inflating: ./our_data/crops/4521.png
#   inflating: ./our_data/crops/4533.png
#   inflating: ./our_data/crops/4537.png
#   inflating: ./our_data/crops/4545.png
#   inflating: ./our_data/crops/4556.png
#   inflating: ./our_data/crops/4557.png
#   inflating: ./our_data/crops/4567.png
#   inflating: ./our_data/crops/4568.png
#   inflating: ./our_data/crops/4574.png
#   inflating: ./our_data/crops/4591.png
#   inflating: ./our_data/crops/4592.png
#   inflating: ./our_data/crops/4599.png
#   inflating: ./our_data/crops/4611.png
#   inflating: ./our_data/crops/4614.png
#   inflating: ./our_data/crops/4624.png
#   inflating: ./our_data/crops/4631.png
#   inflating: ./our_data/crops/4634.png
#   inflating: ./our_data/crops/4635.png
#   inflating: ./our_data/crops/4639.png
#   inflating: ./our_data/crops/4643.png
#   inflating: ./our_data/crops/4652.png
#   inflating: ./our_data/crops/4685.png
#   inflating: ./our_data/crops/4692.png
#   inflating: ./our_data/crops/4694.png
#   inflating: ./our_data/crops/4699.png
#   inflating: ./our_data/crops/4702.png
#   inflating: ./our_data/crops/4704.png
#   inflating: ./our_data/crops/4720.png
#   inflating: ./our_data/crops/4742.png
#   inflating: ./our_data/crops/4744.png
#   inflating: ./our_data/crops/4746.png
#   inflating: ./our_data/crops/4762.png
#   inflating: ./our_data/crops/4766.png
#   inflating: ./our_data/crops/4771.png
#   inflating: ./our_data/crops/4773.png
#   inflating: ./our_data/crops/4780.png
#   inflating: ./our_data/crops/4784.png
#   inflating: ./our_data/crops/4790.png
#   inflating: ./our_data/crops/4793.png
#   inflating: ./our_data/crops/4794.png
#   inflating: ./our_data/crops/4799.png
#   inflating: ./our_data/crops/4814.png
#   inflating: ./our_data/crops/4823.png
#   inflating: ./our_data/crops/4831.png
#   inflating: ./our_data/crops/4841.png
#   inflating: ./our_data/crops/4847.png
#   inflating: ./our_data/crops/4849.png
#   inflating: ./our_data/crops/4855.png
#   inflating: ./our_data/crops/4880.png
#   inflating: ./our_data/crops/4885.png
#   inflating: ./our_data/crops/4910.png
#   inflating: ./our_data/crops/4927.png
#   inflating: ./our_data/crops/4964.png
#   inflating: ./our_data/crops/4967.png
#   inflating: ./our_data/crops/4968.png
#   inflating: ./our_data/crops/4993.png
#   inflating: ./our_data/crops/5010.png
#   inflating: ./our_data/crops/5012.png
#   inflating: ./our_data/crops/5030.png
#   inflating: ./our_data/crops/5031.png
#   inflating: ./our_data/crops/5041.png
#   inflating: ./our_data/crops/5045.png
#   inflating: ./our_data/crops/5058.png
#   inflating: ./our_data/crops/5059.png
#   inflating: ./our_data/crops/5062.png
#   inflating: ./our_data/crops/5066.png
#   inflating: ./our_data/crops/5070.png
#   inflating: ./our_data/crops/5079.png
#   inflating: ./our_data/crops/5080.png
#   inflating: ./our_data/crops/5082.png
#   inflating: ./our_data/crops/5083.png
#   inflating: ./our_data/crops/5092.png
#   inflating: ./our_data/crops/5096.png
#   inflating: ./our_data/crops/5099.png
#   inflating: ./our_data/crops/5107.png
#   inflating: ./our_data/crops/5122.png
#   inflating: ./our_data/crops/5127.png
#   inflating: ./our_data/crops/5130.png
#   inflating: ./our_data/crops/5131.png
#   inflating: ./our_data/crops/5136.png
#   inflating: ./our_data/crops/5144.png
#   inflating: ./our_data/crops/5148.png
#   inflating: ./our_data/crops/5155.png
#   inflating: ./our_data/crops/5162.png
#   inflating: ./our_data/crops/5167.png
#   inflating: ./our_data/crops/5168.png
#   inflating: ./our_data/crops/5170.png
#   inflating: ./our_data/crops/5179.png
#   inflating: ./our_data/crops/5181.png
#   inflating: ./our_data/crops/5189.png
#   inflating: ./our_data/crops/5206.png
#   inflating: ./our_data/crops/5211.png
#   inflating: ./our_data/crops/5218.png
#   inflating: ./our_data/crops/5254.png
#   inflating: ./our_data/crops/5257.png
#   inflating: ./our_data/crops/5258.png
#   inflating: ./our_data/crops/5268.png
#   inflating: ./our_data/crops/5269.png
#   inflating: ./our_data/crops/5277.png
#   inflating: ./our_data/crops/5289.png
#   inflating: ./our_data/crops/5296.png
#   inflating: ./our_data/crops/5307.png
#   inflating: ./our_data/crops/5317.png
#   inflating: ./our_data/crops/5323.png
#   inflating: ./our_data/crops/5324.png
#   inflating: ./our_data/crops/5325.png
#   inflating: ./our_data/crops/5333.png
#   inflating: ./our_data/crops/5337.png
#   inflating: ./our_data/crops/5339.png
#   inflating: ./our_data/crops/5340.png
#   inflating: ./our_data/crops/5357.png
#   inflating: ./our_data/crops/5367.png
#   inflating: ./our_data/crops/5369.png
#   inflating: ./our_data/crops/5371.png
#   inflating: ./our_data/crops/5398.png
#   inflating: ./our_data/crops/5405.png
#   inflating: ./our_data/crops/5428.png
#   inflating: ./our_data/crops/5433.png
#   inflating: ./our_data/crops/5454.png
#   inflating: ./our_data/crops/5471.png
#   inflating: ./our_data/crops/5486.png
#   inflating: ./our_data/crops/5516.png
#   inflating: ./our_data/crops/5519.png
#   inflating: ./our_data/crops/5523.png
#   inflating: ./our_data/crops/5524.png
#   inflating: ./our_data/crops/5555.png
#   inflating: ./our_data/crops/5557.png
#   inflating: ./our_data/crops/5561.png
#   inflating: ./our_data/crops/5564.png
#   inflating: ./our_data/crops/5565.png
#   inflating: ./our_data/crops/5567.png
#   inflating: ./our_data/crops/5575.png
#   inflating: ./our_data/crops/5581.png
#   inflating: ./our_data/crops/5587.png
#   inflating: ./our_data/crops/5588.png
#   inflating: ./our_data/crops/5610.png
#   inflating: ./our_data/crops/5618.png
#   inflating: ./our_data/crops/5641.png
#   inflating: ./our_data/crops/5642.png
#   inflating: ./our_data/crops/5647.png
#   inflating: ./our_data/crops/5663.png
#   inflating: ./our_data/crops/5668.png
#   inflating: ./our_data/crops/5686.png
#   inflating: ./our_data/crops/5688.png
#   inflating: ./our_data/crops/5689.png
#   inflating: ./our_data/crops/5707.png
#   inflating: ./our_data/crops/5710.png
#   inflating: ./our_data/crops/5730.png
#   inflating: ./our_data/crops/5734.png
#   inflating: ./our_data/crops/5747.png
#   inflating: ./our_data/crops/5759.png
#   inflating: ./our_data/crops/5772.png
#   inflating: ./our_data/crops/5774.png
#   inflating: ./our_data/crops/5776.png
#   inflating: ./our_data/crops/5795.png
#   inflating: ./our_data/crops/5805.png
#   inflating: ./our_data/crops/5840.png
#   inflating: ./our_data/crops/5846.png
#   inflating: ./our_data/crops/5856.png
#   inflating: ./our_data/crops/5864.png
#   inflating: ./our_data/crops/5865.png
#   inflating: ./our_data/crops/5874.png
#   inflating: ./our_data/crops/5885.png
#   inflating: ./our_data/crops/5901.png
#   inflating: ./our_data/crops/5908.png
#   inflating: ./our_data/crops/5915.png
#   inflating: ./our_data/crops/5926.png
#   inflating: ./our_data/crops/5953.png
#   inflating: ./our_data/crops/5959.png
#   inflating: ./our_data/crops/5989.png
#   inflating: ./our_data/crops/6009.png
#   inflating: ./our_data/crops/6018.png
#   inflating: ./our_data/crops/6020.png
#   inflating: ./our_data/crops/6032.png
#   inflating: ./our_data/crops/6038.png
#   inflating: ./our_data/crops/6041.png
#   inflating: ./our_data/crops/6051.png
#   inflating: ./our_data/crops/6066.png
#   inflating: ./our_data/crops/6067.png
#   inflating: ./our_data/crops/6077.png
#   inflating: ./our_data/crops/6090.png
#   inflating: ./our_data/crops/6104.png
#   inflating: ./our_data/crops/6119.png
#   inflating: ./our_data/crops/6121.png
#   inflating: ./our_data/crops/6138.png
#   inflating: ./our_data/crops/6161.png
#   inflating: ./our_data/crops/6165.png
#   inflating: ./our_data/crops/6172.png
#   inflating: ./our_data/crops/6173.png
#   inflating: ./our_data/crops/6174.png
#   inflating: ./our_data/crops/6179.png
#   inflating: ./our_data/crops/6180.png
#   inflating: ./our_data/crops/6192.png
#   inflating: ./our_data/crops/6203.png
#   inflating: ./our_data/crops/6206.png
#   inflating: ./our_data/crops/6214.png
#   inflating: ./our_data/crops/6215.png
#   inflating: ./our_data/crops/6232.png
#   inflating: ./our_data/crops/6246.png
#   inflating: ./our_data/crops/6247.png
#   inflating: ./our_data/crops/6250.png
#   inflating: ./our_data/crops/6265.png
#   inflating: ./our_data/crops/6268.png
#   inflating: ./our_data/crops/6275.png
#   inflating: ./our_data/crops/6278.png
#   inflating: ./our_data/crops/6284.png
#   inflating: ./our_data/crops/6285.png
#   inflating: ./our_data/crops/6286.png
#   inflating: ./our_data/crops/6294.png
#   inflating: ./our_data/crops/6296.png
#   inflating: ./our_data/crops/6323.png
#   inflating: ./our_data/crops/6329.png
#   inflating: ./our_data/crops/6351.png
#   inflating: ./our_data/crops/6358.png
#   inflating: ./our_data/crops/6360.png
#   inflating: ./our_data/crops/6361.png
#   inflating: ./our_data/crops/6366.png
#   inflating: ./our_data/crops/6380.png
#   inflating: ./our_data/crops/6384.png
#   inflating: ./our_data/crops/6387.png
#   inflating: ./our_data/crops/6389.png
#   inflating: ./our_data/crops/6392.png
#   inflating: ./our_data/crops/6395.png
#   inflating: ./our_data/crops/6399.png
#   inflating: ./our_data/crops/6400.png
#   inflating: ./our_data/crops/6404.png
#   inflating: ./our_data/crops/6405.png
#   inflating: ./our_data/crops/6408.png
#   inflating: ./our_data/crops/6415.png
#   inflating: ./our_data/crops/6426.png
#   inflating: ./our_data/crops/6428.png
#   inflating: ./our_data/crops/6437.png
#   inflating: ./our_data/crops/6440.png
#   inflating: ./our_data/crops/6458.png
#   inflating: ./our_data/crops/6468.png
#   inflating: ./our_data/crops/6472.png
#   inflating: ./our_data/crops/6481.png
#   inflating: ./our_data/crops/6499.png
#   inflating: ./our_data/crops/6515.png
#   inflating: ./our_data/crops/6526.png
#   inflating: ./our_data/crops/6527.png
#   inflating: ./our_data/crops/6533.png
#   inflating: ./our_data/crops/6544.png
#   inflating: ./our_data/crops/6545.png
#   inflating: ./our_data/crops/6553.png
#   inflating: ./our_data/crops/6557.png
#   inflating: ./our_data/crops/6577.png
#   inflating: ./our_data/crops/6580.png
#   inflating: ./our_data/crops/6583.png
#   inflating: ./our_data/crops/6602.png
#   inflating: ./our_data/crops/6612.png
#   inflating: ./our_data/crops/6622.png
#   inflating: ./our_data/crops/6623.png
#   inflating: ./our_data/crops/6634.png
#   inflating: ./our_data/crops/6642.png
#   inflating: ./our_data/crops/6651.png
#   inflating: ./our_data/crops/6654.png
#   inflating: ./our_data/crops/6696.png
#   inflating: ./our_data/crops/6699.png
#   inflating: ./our_data/crops/6701.png
#   inflating: ./our_data/crops/6705.png
#   inflating: ./our_data/crops/6708.png
#   inflating: ./our_data/crops/6735.png
#   inflating: ./our_data/crops/6747.png
#   inflating: ./our_data/crops/6755.png
#   inflating: ./our_data/crops/6758.png
#   inflating: ./our_data/crops/6769.png
#   inflating: ./our_data/crops/6771.png
#   inflating: ./our_data/crops/6798.png
#   inflating: ./our_data/crops/6814.png
#   inflating: ./our_data/crops/6816.png
#   inflating: ./our_data/crops/6827.png
#   inflating: ./our_data/crops/6828.png
#   inflating: ./our_data/crops/6840.png
#   inflating: ./our_data/crops/6841.png
#   inflating: ./our_data/crops/6847.png
#   inflating: ./our_data/crops/6859.png
#   inflating: ./our_data/crops/6861.png
#   inflating: ./our_data/crops/6863.png
#   inflating: ./our_data/crops/6868.png
#   inflating: ./our_data/crops/6869.png
#   inflating: ./our_data/crops/6879.png
#   inflating: ./our_data/crops/6884.png
#   inflating: ./our_data/crops/6894.png
#   inflating: ./our_data/crops/6895.png
#   inflating: ./our_data/crops/6897.png
#   inflating: ./our_data/crops/6900.png
#   inflating: ./our_data/crops/6902.png
#   inflating: ./our_data/crops/6910.png
#   inflating: ./our_data/crops/6933.png
#   inflating: ./our_data/crops/6935.png
#   inflating: ./our_data/crops/6937.png
#   inflating: ./our_data/crops/6953.png
#   inflating: ./our_data/crops/6958.png
#   inflating: ./our_data/crops/6974.png
#   inflating: ./our_data/crops/6977.png
#   inflating: ./our_data/crops/6982.png
#   inflating: ./our_data/crops/6991.png
#   inflating: ./our_data/crops/7005.png
#   inflating: ./our_data/crops/7015.png
#   inflating: ./our_data/crops/7016.png
#   inflating: ./our_data/crops/7017.png
#   inflating: ./our_data/crops/7019.png
#   inflating: ./our_data/crops/7031.png
#   inflating: ./our_data/crops/7033.png
#   inflating: ./our_data/crops/7068.png
#   inflating: ./our_data/crops/7075.png
#   inflating: ./our_data/crops/7086.png
#   inflating: ./our_data/crops/7097.png
#   inflating: ./our_data/crops/7107.png
#   inflating: ./our_data/crops/7112.png
#   inflating: ./our_data/crops/7115.png
#   inflating: ./our_data/crops/7127.png
#   inflating: ./our_data/crops/7149.png
#   inflating: ./our_data/crops/7150.png
#   inflating: ./our_data/crops/7153.png
#   inflating: ./our_data/crops/7163.png
#   inflating: ./our_data/crops/7167.png
#   inflating: ./our_data/crops/7168.png
#   inflating: ./our_data/crops/7176.png
#   inflating: ./our_data/crops/7190.png
#   inflating: ./our_data/crops/7225.png
#   inflating: ./our_data/crops/7244.png
#   inflating: ./our_data/crops/7245.png
#   inflating: ./our_data/crops/7248.png
#   inflating: ./our_data/crops/7264.png
#   inflating: ./our_data/crops/7265.png
#   inflating: ./our_data/crops/7266.png
#   inflating: ./our_data/crops/7269.png
#   inflating: ./our_data/crops/7282.png
#   inflating: ./our_data/crops/7288.png
#   inflating: ./our_data/crops/7296.png
#   inflating: ./our_data/crops/7322.png
#   inflating: ./our_data/crops/7329.png
#   inflating: ./our_data/crops/7338.png
#   inflating: ./our_data/crops/7339.png
#   inflating: ./our_data/crops/7353.png
#   inflating: ./our_data/crops/7357.png
#   inflating: ./our_data/crops/7373.png
#   inflating: ./our_data/crops/7374.png
#   inflating: ./our_data/crops/7375.png
#   inflating: ./our_data/crops/7379.png
#   inflating: ./our_data/crops/7395.png
#   inflating: ./our_data/crops/7415.png
#   inflating: ./our_data/crops/7416.png
#   inflating: ./our_data/crops/7419.png
#   inflating: ./our_data/crops/7425.png
#   inflating: ./our_data/crops/7446.png
#   inflating: ./our_data/crops/7450.png
#   inflating: ./our_data/crops/7455.png
#   inflating: ./our_data/crops/7456.png
#   inflating: ./our_data/crops/7467.png
#   inflating: ./our_data/crops/7474.png
#   inflating: ./our_data/crops/7478.png
#   inflating: ./our_data/crops/7488.png
#   inflating: ./our_data/crops/7500.png
#   inflating: ./our_data/crops/7514.png
#   inflating: ./our_data/crops/7520.png
#   inflating: ./our_data/crops/7527.png
#   inflating: ./our_data/crops/7529.png
#   inflating: ./our_data/crops/7535.png
#   inflating: ./our_data/crops/7564.png
#   inflating: ./our_data/crops/7569.png
#   inflating: ./our_data/crops/7570.png
#   inflating: ./our_data/crops/7576.png
#   inflating: ./our_data/crops/7581.png
#   inflating: ./our_data/crops/7592.png
#   inflating: ./our_data/crops/7606.png
#   inflating: ./our_data/crops/7612.png
#   inflating: ./our_data/crops/7614.png
#   inflating: ./our_data/crops/7625.png
#   inflating: ./our_data/crops/7626.png
#   inflating: ./our_data/crops/7628.png
#   inflating: ./our_data/crops/7641.png
#   inflating: ./our_data/crops/7648.png
#   inflating: ./our_data/crops/7666.png
#   inflating: ./our_data/crops/7692.png
#   inflating: ./our_data/crops/7710.png
#   inflating: ./our_data/crops/7712.png
#   inflating: ./our_data/crops/7720.png
#   inflating: ./our_data/crops/7738.png
#   inflating: ./our_data/crops/7742.png
#   inflating: ./our_data/crops/7744.png
#   inflating: ./our_data/crops/7750.png
#   inflating: ./our_data/crops/7754.png
#   inflating: ./our_data/crops/7756.png
#   inflating: ./our_data/crops/7757.png
#   inflating: ./our_data/crops/7760.png
#   inflating: ./our_data/crops/7766.png
#   inflating: ./our_data/crops/7767.png
#   inflating: ./our_data/crops/7771.png
#   inflating: ./our_data/crops/7775.png
#   inflating: ./our_data/crops/7776.png
#   inflating: ./our_data/crops/7777.png
#   inflating: ./our_data/crops/7782.png
#   inflating: ./our_data/crops/7802.png
#   inflating: ./our_data/crops/7805.png
#   inflating: ./our_data/crops/7815.png
#   inflating: ./our_data/crops/7820.png
#   inflating: ./our_data/crops/7821.png
#   inflating: ./our_data/crops/7828.png
#   inflating: ./our_data/crops/7835.png
#   inflating: ./our_data/crops/7843.png
#   inflating: ./our_data/crops/7850.png
#   inflating: ./our_data/crops/7853.png
#   inflating: ./our_data/crops/4.png
#   inflating: ./our_data/crops/8.png
#   inflating: ./our_data/crops/19.png
#   inflating: ./our_data/crops/20.png
#   inflating: ./our_data/crops/28.png
#   inflating: ./our_data/crops/43.png
#   inflating: ./our_data/crops/46.png
#   inflating: ./our_data/crops/58.png
#   inflating: ./our_data/crops/69.png
#   inflating: ./our_data/crops/78.png
#   inflating: ./our_data/crops/81.png
#   inflating: ./our_data/crops/83.png
#   inflating: ./our_data/crops/87.png
#   inflating: ./our_data/crops/94.png
#   inflating: ./our_data/crops/115.png
#   inflating: ./our_data/crops/119.png
#   inflating: ./our_data/crops/127.png
#   inflating: ./our_data/crops/137.png
#   inflating: ./our_data/crops/149.png
#   inflating: ./our_data/crops/157.png
#   inflating: ./our_data/crops/168.png
#   inflating: ./our_data/crops/172.png
#   inflating: ./our_data/crops/187.png
#   inflating: ./our_data/crops/191.png
#   inflating: ./our_data/crops/192.png
#   inflating: ./our_data/crops/199.png
#   inflating: ./our_data/crops/223.png
#   inflating: ./our_data/crops/224.png
#   inflating: ./our_data/crops/234.png
#   inflating: ./our_data/crops/238.png
#   inflating: ./our_data/crops/240.png
#   inflating: ./our_data/crops/252.png
# ...
#   inflating: ./our_data/crops/4237.png
#   inflating: ./our_data/crops/4238.png
#   inflating: ./our_data/crops/4240.png
#   inflating: ./our_data/crops/4242.png
#   inflating: ./our_data/crops/4290.png
#   inflating: ./our_data/crops/4326.png
#   inflating: ./our_data/crops/4331.png
#   inflating: ./our_data/crops/4336.png
#   inflating: ./our_data/crops/4342.png
#   inflating: ./our_data/crops/4358.png
#   inflating: ./our_data/crops/4366.png
#   inflating: ./our_data/crops/4368.png
#   inflating: ./our_data/crops/4379.png
#   inflating: ./our_data/crops/4382.png
#   inflating: ./our_data/crops/4407.png
#   inflating: ./our_data/crops/4410.png
#   inflating: ./our_data/crops/4412.png
#   inflating: ./our_data/crops/4418.png
#   inflating: ./our_data/crops/4443.png
#   inflating: ./our_data/crops/4447.png
#   inflating: ./our_data/crops/4453.png
#   inflating: ./our_data/crops/4476.png
#   inflating: ./our_data/crops/4516.png
#   inflating: ./our_data/crops/4518.png
#   inflating: ./our_data/crops/4524.png
#   inflating: ./our_data/crops/4531.png
#   inflating: ./our_data/crops/4544.png
#   inflating: ./our_data/crops/4550.png
#   inflating: ./our_data/crops/4566.png
#   inflating: ./our_data/crops/4572.png
#   inflating: ./our_data/crops/4589.png
#   inflating: ./our_data/crops/4593.png
#   inflating: ./our_data/crops/4603.png
#   inflating: ./our_data/crops/4612.png
#   inflating: ./our_data/crops/4630.png
#   inflating: ./our_data/crops/4638.png
#   inflating: ./our_data/crops/4644.png
#   inflating: ./our_data/crops/4650.png
#   inflating: ./our_data/crops/4670.png
#   inflating: ./our_data/crops/4671.png
#   inflating: ./our_data/crops/4676.png
#   inflating: ./our_data/crops/4679.png
#   inflating: ./our_data/crops/4686.png
#   inflating: ./our_data/crops/4700.png
#   inflating: ./our_data/crops/4713.png
#   inflating: ./our_data/crops/4723.png
#   inflating: ./our_data/crops/4726.png
#   inflating: ./our_data/crops/4732.png
#   inflating: ./our_data/crops/4733.png
#   inflating: ./our_data/crops/4738.png
#   inflating: ./our_data/crops/4745.png
#   inflating: ./our_data/crops/4751.png
#   inflating: ./our_data/crops/4760.png
#   inflating: ./our_data/crops/4777.png
#   inflating: ./our_data/crops/4781.png
#   inflating: ./our_data/crops/4786.png
#   inflating: ./our_data/crops/4795.png
#   inflating: ./our_data/crops/4813.png
#   inflating: ./our_data/crops/4827.png
#   inflating: ./our_data/crops/4851.png
#   inflating: ./our_data/crops/4857.png
#   inflating: ./our_data/crops/4891.png
#   inflating: ./our_data/crops/4894.png
#   inflating: ./our_data/crops/4909.png
#   inflating: ./our_data/crops/4915.png
#   inflating: ./our_data/crops/4941.png
#   inflating: ./our_data/crops/4947.png
#   inflating: ./our_data/crops/4957.png
#   inflating: ./our_data/crops/4965.png
#   inflating: ./our_data/crops/4969.png
#   inflating: ./our_data/crops/4971.png
#   inflating: ./our_data/crops/4989.png
#   inflating: ./our_data/crops/4999.png
#   inflating: ./our_data/crops/5001.png
#   inflating: ./our_data/crops/5008.png
#   inflating: ./our_data/crops/5017.png
#   inflating: ./our_data/crops/5020.png
#   inflating: ./our_data/crops/5029.png
#   inflating: ./our_data/crops/5032.png
#   inflating: ./our_data/crops/5047.png
#   inflating: ./our_data/crops/5052.png
#   inflating: ./our_data/crops/5055.png
#   inflating: ./our_data/crops/5071.png
#   inflating: ./our_data/crops/5075.png
#   inflating: ./our_data/crops/5086.png
#   inflating: ./our_data/crops/5093.png
#   inflating: ./our_data/crops/5103.png
#   inflating: ./our_data/crops/5111.png
#   inflating: ./our_data/crops/5135.png
#   inflating: ./our_data/crops/5137.png
#   inflating: ./our_data/crops/5149.png
#   inflating: ./our_data/crops/5150.png
#   inflating: ./our_data/crops/5158.png
#   inflating: ./our_data/crops/5159.png
#   inflating: ./our_data/crops/5164.png
#   inflating: ./our_data/crops/5165.png
#   inflating: ./our_data/crops/5175.png
#   inflating: ./our_data/crops/5182.png
#   inflating: ./our_data/crops/5183.png
#   inflating: ./our_data/crops/5197.png
#   inflating: ./our_data/crops/5207.png
#   inflating: ./our_data/crops/5210.png
#   inflating: ./our_data/crops/5219.png
#   inflating: ./our_data/crops/5249.png
#   inflating: ./our_data/crops/5253.png
#   inflating: ./our_data/crops/5281.png
#   inflating: ./our_data/crops/5285.png
#   inflating: ./our_data/crops/5293.png
#   inflating: ./our_data/crops/5304.png
#   inflating: ./our_data/crops/5316.png
#   inflating: ./our_data/crops/5326.png
#   inflating: ./our_data/crops/5327.png
#   inflating: ./our_data/crops/5348.png
#   inflating: ./our_data/crops/5352.png
#   inflating: ./our_data/crops/5360.png
#   inflating: ./our_data/crops/5365.png
#   inflating: ./our_data/crops/5366.png
#   inflating: ./our_data/crops/5375.png
#   inflating: ./our_data/crops/5384.png
#   inflating: ./our_data/crops/5390.png
#   inflating: ./our_data/crops/5397.png
#   inflating: ./our_data/crops/5402.png
#   inflating: ./our_data/crops/5410.png
#   inflating: ./our_data/crops/5413.png
#   inflating: ./our_data/crops/5422.png
#   inflating: ./our_data/crops/5435.png
#   inflating: ./our_data/crops/5437.png
#   inflating: ./our_data/crops/5440.png
#   inflating: ./our_data/crops/5442.png
#   inflating: ./our_data/crops/5444.png
#   inflating: ./our_data/crops/5459.png
#   inflating: ./our_data/crops/5461.png
#   inflating: ./our_data/crops/5463.png
#   inflating: ./our_data/crops/5483.png
#   inflating: ./our_data/crops/5495.png
#   inflating: ./our_data/crops/5496.png
#   inflating: ./our_data/crops/5498.png
#   inflating: ./our_data/crops/5518.png
#   inflating: ./our_data/crops/5522.png
#   inflating: ./our_data/crops/5528.png
#   inflating: ./our_data/crops/5530.png
#   inflating: ./our_data/crops/5537.png
#   inflating: ./our_data/crops/5549.png
#   inflating: ./our_data/crops/5576.png
#   inflating: ./our_data/crops/5582.png
#   inflating: ./our_data/crops/5585.png
#   inflating: ./our_data/crops/5593.png
#   inflating: ./our_data/crops/5600.png
#   inflating: ./our_data/crops/5604.png
#   inflating: ./our_data/crops/5611.png
#   inflating: ./our_data/crops/5626.png
#   inflating: ./our_data/crops/5658.png
#   inflating: ./our_data/crops/5661.png
#   inflating: ./our_data/crops/5665.png
#   inflating: ./our_data/crops/5667.png
#   inflating: ./our_data/crops/5670.png
#   inflating: ./our_data/crops/5675.png
#   inflating: ./our_data/crops/5676.png
#   inflating: ./our_data/crops/5677.png
#   inflating: ./our_data/crops/5722.png
#   inflating: ./our_data/crops/5740.png
#   inflating: ./our_data/crops/5773.png
#   inflating: ./our_data/crops/5786.png
#   inflating: ./our_data/crops/5787.png
#   inflating: ./our_data/crops/5788.png
#   inflating: ./our_data/crops/5794.png
#   inflating: ./our_data/crops/5796.png
#   inflating: ./our_data/crops/5822.png
#   inflating: ./our_data/crops/5831.png
#   inflating: ./our_data/crops/5866.png
#   inflating: ./our_data/crops/5876.png
#   inflating: ./our_data/crops/5893.png
#   inflating: ./our_data/crops/5894.png
#   inflating: ./our_data/crops/5931.png
#   inflating: ./our_data/crops/5946.png
#   inflating: ./our_data/crops/5949.png
#   inflating: ./our_data/crops/5955.png
#   inflating: ./our_data/crops/5960.png
#   inflating: ./our_data/crops/5961.png
#   inflating: ./our_data/crops/5972.png
#   inflating: ./our_data/crops/5978.png
#   inflating: ./our_data/crops/5986.png
#   inflating: ./our_data/crops/5987.png
#   inflating: ./our_data/crops/5993.png
#   inflating: ./our_data/crops/5995.png
#   inflating: ./our_data/crops/6005.png
#   inflating: ./our_data/crops/6007.png
#   inflating: ./our_data/crops/6008.png
#   inflating: ./our_data/crops/6016.png
#   inflating: ./our_data/crops/6023.png
#   inflating: ./our_data/crops/6033.png
#   inflating: ./our_data/crops/6046.png
#   inflating: ./our_data/crops/6057.png
#   inflating: ./our_data/crops/6116.png
#   inflating: ./our_data/crops/6125.png
#   inflating: ./our_data/crops/6166.png
#   inflating: ./our_data/crops/6167.png
#   inflating: ./our_data/crops/6185.png
#   inflating: ./our_data/crops/6213.png
#   inflating: ./our_data/crops/6219.png
#   inflating: ./our_data/crops/6220.png
#   inflating: ./our_data/crops/6222.png
#   inflating: ./our_data/crops/6224.png
#   inflating: ./our_data/crops/6236.png
#   inflating: ./our_data/crops/6243.png
#   inflating: ./our_data/crops/6253.png
#   inflating: ./our_data/crops/6282.png
#   inflating: ./our_data/crops/6297.png
#   inflating: ./our_data/crops/6310.png
#   inflating: ./our_data/crops/6311.png
#   inflating: ./our_data/crops/6312.png
#   inflating: ./our_data/crops/6317.png
#   inflating: ./our_data/crops/6318.png
#   inflating: ./our_data/crops/6324.png
#   inflating: ./our_data/crops/6334.png
#   inflating: ./our_data/crops/6348.png
#   inflating: ./our_data/crops/6364.png
#   inflating: ./our_data/crops/6368.png
#   inflating: ./our_data/crops/6369.png
#   inflating: ./our_data/crops/6372.png
#   inflating: ./our_data/crops/6373.png
#   inflating: ./our_data/crops/6402.png
#   inflating: ./our_data/crops/6432.png
#   inflating: ./our_data/crops/6436.png
#   inflating: ./our_data/crops/6448.png
#   inflating: ./our_data/crops/6456.png
#   inflating: ./our_data/crops/6461.png
#   inflating: ./our_data/crops/6465.png
#   inflating: ./our_data/crops/6466.png
#   inflating: ./our_data/crops/6469.png
#   inflating: ./our_data/crops/6474.png
#   inflating: ./our_data/crops/6488.png
#   inflating: ./our_data/crops/6490.png
#   inflating: ./our_data/crops/6502.png
#   inflating: ./our_data/crops/6507.png
#   inflating: ./our_data/crops/6513.png
#   inflating: ./our_data/crops/6514.png
#   inflating: ./our_data/crops/6517.png
#   inflating: ./our_data/crops/6524.png
#   inflating: ./our_data/crops/6531.png
#   inflating: ./our_data/crops/6534.png
#   inflating: ./our_data/crops/6559.png
#   inflating: ./our_data/crops/6562.png
#   inflating: ./our_data/crops/6568.png
#   inflating: ./our_data/crops/6571.png
#   inflating: ./our_data/crops/6573.png
#   inflating: ./our_data/crops/6601.png
#   inflating: ./our_data/crops/6604.png
#   inflating: ./our_data/crops/6613.png
#   inflating: ./our_data/crops/6626.png
#   inflating: ./our_data/crops/6629.png
#   inflating: ./our_data/crops/6638.png
#   inflating: ./our_data/crops/6639.png
#   inflating: ./our_data/crops/6644.png
#   inflating: ./our_data/crops/6645.png
#   inflating: ./our_data/crops/6647.png
#   inflating: ./our_data/crops/6664.png
#   inflating: ./our_data/crops/6671.png
#   inflating: ./our_data/crops/6675.png
#   inflating: ./our_data/crops/6676.png
#   inflating: ./our_data/crops/6689.png
#   inflating: ./our_data/crops/6694.png
#   inflating: ./our_data/crops/6697.png
#   inflating: ./our_data/crops/6704.png
#   inflating: ./our_data/crops/6720.png
#   inflating: ./our_data/crops/6724.png
#   inflating: ./our_data/crops/6756.png
#   inflating: ./our_data/crops/6763.png
#   inflating: ./our_data/crops/6774.png
#   inflating: ./our_data/crops/6775.png
#   inflating: ./our_data/crops/6781.png
#   inflating: ./our_data/crops/6784.png
#   inflating: ./our_data/crops/6803.png
#   inflating: ./our_data/crops/6807.png
#   inflating: ./our_data/crops/6817.png
#   inflating: ./our_data/crops/6822.png
#   inflating: ./our_data/crops/6837.png
#   inflating: ./our_data/crops/6851.png
#   inflating: ./our_data/crops/6853.png
#   inflating: ./our_data/crops/6875.png
#   inflating: ./our_data/crops/6876.png
#   inflating: ./our_data/crops/6881.png
#   inflating: ./our_data/crops/6891.png
#   inflating: ./our_data/crops/6892.png
#   inflating: ./our_data/crops/6916.png
#   inflating: ./our_data/crops/6925.png
#   inflating: ./our_data/crops/6926.png
#   inflating: ./our_data/crops/6948.png
#   inflating: ./our_data/crops/6954.png
#   inflating: ./our_data/crops/6969.png
#   inflating: ./our_data/crops/7000.png
#   inflating: ./our_data/crops/7006.png
#   inflating: ./our_data/crops/7009.png
#   inflating: ./our_data/crops/7018.png
#   inflating: ./our_data/crops/7048.png
#   inflating: ./our_data/crops/7051.png
#   inflating: ./our_data/crops/7076.png
#   inflating: ./our_data/crops/7081.png
#   inflating: ./our_data/crops/7088.png
#   inflating: ./our_data/crops/7093.png
#   inflating: ./our_data/crops/7094.png
#   inflating: ./our_data/crops/7111.png
#   inflating: ./our_data/crops/7119.png
#   inflating: ./our_data/crops/7121.png
#   inflating: ./our_data/crops/7125.png
#   inflating: ./our_data/crops/7128.png
#   inflating: ./our_data/crops/7136.png
#   inflating: ./our_data/crops/7139.png
#   inflating: ./our_data/crops/7141.png
#   inflating: ./our_data/crops/7151.png
#   inflating: ./our_data/crops/7180.png
#   inflating: ./our_data/crops/7201.png
#   inflating: ./our_data/crops/7215.png
#   inflating: ./our_data/crops/7222.png
#   inflating: ./our_data/crops/7233.png
#   inflating: ./our_data/crops/7252.png
#   inflating: ./our_data/crops/7253.png
#   inflating: ./our_data/crops/7256.png
#   inflating: ./our_data/crops/7272.png
#   inflating: ./our_data/crops/7297.png
#   inflating: ./our_data/crops/7299.png
#   inflating: ./our_data/crops/7304.png
#   inflating: ./our_data/crops/7325.png
#   inflating: ./our_data/crops/7327.png
#   inflating: ./our_data/crops/7343.png
#   inflating: ./our_data/crops/7347.png
#   inflating: ./our_data/crops/7358.png
#   inflating: ./our_data/crops/7368.png
#   inflating: ./our_data/crops/7380.png
#   inflating: ./our_data/crops/7381.png
#   inflating: ./our_data/crops/7386.png
#   inflating: ./our_data/crops/7388.png
#   inflating: ./our_data/crops/7404.png
#   inflating: ./our_data/crops/7409.png
#   inflating: ./our_data/crops/7429.png
#   inflating: ./our_data/crops/7451.png
#   inflating: ./our_data/crops/7453.png
#   inflating: ./our_data/crops/7459.png
#   inflating: ./our_data/crops/7460.png
#   inflating: ./our_data/crops/7461.png
#   inflating: ./our_data/crops/7471.png
#   inflating: ./our_data/crops/7477.png
#   inflating: ./our_data/crops/7491.png
#   inflating: ./our_data/crops/7510.png
#   inflating: ./our_data/crops/7515.png
#   inflating: ./our_data/crops/7533.png
#   inflating: ./our_data/crops/7536.png
#   inflating: ./our_data/crops/7540.png
#   inflating: ./our_data/crops/7541.png
#   inflating: ./our_data/crops/7556.png
#   inflating: ./our_data/crops/7558.png
#   inflating: ./our_data/crops/7560.png
#   inflating: ./our_data/crops/7571.png
#   inflating: ./our_data/crops/7573.png
#   inflating: ./our_data/crops/7575.png
#   inflating: ./our_data/crops/7579.png
#   inflating: ./our_data/crops/7596.png
#   inflating: ./our_data/crops/7598.png
#   inflating: ./our_data/crops/7609.png
#   inflating: ./our_data/crops/7633.png
#   inflating: ./our_data/crops/7645.png
#   inflating: ./our_data/crops/7646.png
#   inflating: ./our_data/crops/7653.png
#   inflating: ./our_data/crops/7655.png
#   inflating: ./our_data/crops/7658.png
#   inflating: ./our_data/crops/7660.png
#   inflating: ./our_data/crops/7665.png
#   inflating: ./our_data/crops/7674.png
#   inflating: ./our_data/crops/7693.png
#   inflating: ./our_data/crops/7695.png
#   inflating: ./our_data/crops/7699.png
#   inflating: ./our_data/crops/7711.png
#   inflating: ./our_data/crops/7721.png
#   inflating: ./our_data/crops/7734.png
#   inflating: ./our_data/crops/7735.png
#   inflating: ./our_data/crops/7770.png
#   inflating: ./our_data/crops/7779.png
#   inflating: ./our_data/crops/7780.png
#   inflating: ./our_data/crops/7786.png
#   inflating: ./our_data/crops/7804.png
#   inflating: ./our_data/crops/7811.png
#   inflating: ./our_data/crops/7813.png
#   inflating: ./our_data/crops/7817.png
#   inflating: ./our_data/crops/7822.png
#   inflating: ./our_data/crops/7824.png
#   inflating: ./our_data/crops/7832.png
#   inflating: ./our_data/crops/7849.png
#   inflating: ./our_data/crops/7856.png
#   inflating: ./our_data/test.json
#   inflating: ./our_data/train.json

# %%
# !nvidia-smi
# Out:
# Sun Dec 18 13:34:14 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0    33W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch
import numpy as np
from os import listdir, readlink
from os.path import join
from torch.utils.data import Dataset
import torchvision.transforms.functional as TF
import cv2

def get_parameters(models):
    r"""
    This function get all the parameter recursive exploring the dictionary, list or module in input if necessary
    """
    parameters = []
    if isinstance(models, list):
        for model in models:
            parameters += get_parameters(model)
    elif isinstance(models, dict):
        for model in models.values():
            parameters += get_parameters(model)
    else: # models is actually a single pytorch model
        parameters += [p for p in models.parameters() if p.requires_grad]
    return parameters


class DLC2021_FDA(Dataset):
    '''
    Dataset to handle image loading and transformations
    '''

    def __init__(self, root_source, root_target, split_source, split_target, beta_fda=(0,0.01), image_size=(224,224)):
        super(DLC2021_FDA, self).__init__()

        self.tgt_root = root_target
        self.src_root = root_source
        self.tgt_split = split_target
        self.src_split = split_source
        self.image_size = image_size
        self.beta_fda = beta_fda

        # read annots data
        with open(join(self.src_root, 'annots.json')) as f:
            self.src_data = json.load(f)
        
        with open(join(self.src_root, f'{self.src_split}.json')) as f:
            self.src_ids = json.load(f)

        with open(join(self.tgt_root, 'annots.json')) as f:
            self.tgt_data = json.load(f)
        
        with open(join(self.tgt_root, f'{self.tgt_split}.json')) as f:
            self.tgt_ids = json.load(f)

    def __getitem__(self, index):
    
        # get and load infor about src image
        index = str(self.src_ids[index])
        img_label = self.src_data[index]['label'] 
        img_id = self.src_data[index]['id'] 
        path = join(self.src_root, 'crops',f'{img_id}.png')
        img = cv2.imread(path)
        img = torch.tensor(np.asarray(img).transpose(2,0,1), dtype=torch.float)
        
        # get and load info about tgt image
        tgt_index = np.random.randint(0,len(self.tgt_ids))
        tgt_id = str(self.tgt_ids[tgt_index])
        path = join(self.tgt_root, 'crops', f'{tgt_id}.png')
        tgt_img = cv2.imread(path)
        tgt_img = torch.tensor(np.asarray(tgt_img).transpose(2,0,1), dtype=torch.float)
        
        # apply fda and fix bounds
        mod_img = apply_fda(img, tgt_img, self.beta_fda)
        # fix bounds by re-normalizing between 0 and 1
        min_b, max_b = torch.amin(mod_img, dim=(1,2)), torch.amax(mod_img, dim=(1,2))
        min_b, max_b = min_b.view(3,1,1), max_b.view(3,1,1)

        mod_img = 255 * (mod_img - min_b) / (max_b - min_b)

        #debug_augs(img, mod_img, tgt_img, img_id, tgt_id)

        img = mod_img


        return img, float(img_label), img_id

    def __len__(self):
        return len(self.src_ids)


def debug_augs(src, mod_src, tgt, src_id, tgt_id):

    src = src.numpy().transpose(1,2,0)
    mod_src = mod_src.numpy().transpose(1,2,0)
    tgt = tgt.numpy().transpose(1,2,0)

    cv2.imwrite(f'src_{src_id}.png', src)
    cv2.imwrite(f'mod_src_{src_id}.png', mod_src)
    cv2.imwrite(f'tgt_{tgt_id}.png', tgt)



class DLC2021(Dataset):
    '''
    Dataset to handle image loading and transformations
    '''

    def __init__(self, root, split, image_size=(224,224)):
        super(DLC2021, self).__init__()

        self.root = root
        self.split = split
        self.image_size=[224,224]

        # read annots data
        with open(join(root, 'annots.json')) as f:
            self.data = json.load(f)
        
        with open(join(root, f'{split}.json')) as f:
            self.ids = json.load(f)

    def __getitem__(self, index):
    
        index = str(self.ids[index])
        # read image, produce sample. Removes last two chars (\n) from path
        img_label = self.data[index]['label'] 
        img_id = self.data[index]['id'] 
        path = join(self.root, 'crops',f'{img_id}.png')

        img = cv2.imread(path)
        
        img = torch.tensor(np.asarray(img).transpose(2,0,1), dtype=torch.float)

        # eventually apply augmentations
        #t_sample = self.transforms(img) 

        return img, float(img_label), img_id

    def __len__(self):
        return len(self.ids)

# %%
import math

def apply_fda(source_img, target_img, betas):

    min_b, max_b = betas
    
    # using fft, get source in target in fourier domain
    # this function outputs the fourier transform in complex number
    target_f = torch.fft.fft2(target_img.clone())
    source_f = torch.fft.fft2(source_img.clone()) 

    # switch from complex number formulation to amplitude and phase
    target_amp, source_amp = torch.abs(target_f), torch.abs(source_f)
    # phase of target is not used, only source is necessary
    source_phase = torch.angle(source_f)

    # amplitude is given with positive frequencies first and then negative frequencies
    # fftshift change this to center 0 frequence at the center of the image
    # this makes spectrum substitution easier in the code
    source_shifted_amp = torch.fft.fftshift(source_amp, dim=(-2, -1))
    target_shifted_amp = torch.fft.fftshift(target_amp, dim=(-2, -1))

    # clone source, may be necessary in the frequency interval setting
    source_shifted_amp_clone = source_shifted_amp.clone()

    # get image shape (assuming square image) and compute bounds
    dim = source_shifted_amp.shape[1]
    bound = int(math.floor(dim * max_b))
    img_center = int(math.floor(dim/2))

    l_bound = img_center - bound
    u_bound = img_center + bound + 1

    # substitute frequency
    source_shifted_amp[:,l_bound:u_bound, l_bound:u_bound] = target_shifted_amp[:,l_bound:u_bound, l_bound:u_bound]

    # if this is true, we are in the frequency interval setting
    if min_b > 0:
        # repeat the same operations as above, but restore to the original source the frequencies lower than the bound
        bound = int(math.floor(dim * min_b))
        img_center = int(math.floor(dim/2))

        l_bound = img_center - bound
        u_bound = img_center + bound + 1

        #print('Applying lower bound: {}, {}'.format(l_bound, u_bound))

        source_shifted_amp[:,l_bound:u_bound, l_bound:u_bound] = source_shifted_amp_clone[:,l_bound:u_bound, l_bound:u_bound]

    # finally, get back to the default amplitude representation by inverting the shift operation
    source_new_amp = torch.fft.ifftshift(source_shifted_amp, dim=(-2, -1))
    
    # to reconstruct the image, we need the complex representation of the fourier transform
    # to obtain this, multiply the FDA-augmented amplitude with the exponential of the original source phase
    source_new_f =  source_new_amp * torch.exp(1j * source_phase)

    # finally, invert the fourier transform and get an image back
    source_new_img = torch.fft.ifft2(source_new_f, dim=(-2, -1))
    source_new_img = torch.real(source_new_img)

    return source_new_img

# %%
EXP_ROOT = 'gdrive/MyDrive/TACV_exps'

# %%
import math
import json
import torchinfo
from datetime import datetime
import torch.nn as nn
import logging
import subprocess
import torchvision.models as models
from torch.utils.data import DataLoader
from pytorch_lightning import LightningModule
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.callbacks.progress.tqdm_progress import TQDMProgressBar
from pytorch_lightning.loggers import WandbLogger

class DocRecDetection(LightningModule):
    
    """
    This class is a PyTorch Lightning system and contain the core of the major steps made during the training of a NN
    """

    def __init__(self, config):
        """
        This functions setup the model and the NN loss
        """
        super().__init__()

        self.args = config
        self.init_pipeline()
        
        self.act = torch.nn.Sigmoid()

    def init_pipeline(self):
        
        exp_root = EXP_ROOT + '/{}'.format(self.args['exp_name'])
        # get pretrained Resnet50 on Imagenet

        if self.args['backbone'] == 'mobilenet':
            backbone = models.mobilenet_v3_small(weights="DEFAULT")
            _ = backbone.classifier.pop(-1) 
            backbone.classifier.append(nn.Linear(1024,1))
            #backbone = models.efficientnet_v2_s(weights="DEFAULT")
        
        elif self.args['backbone'] == 'efficientnet':
            backbone = models.efficientnet_v2_s(weights="DEFAULT")
            _ = backbone.classifier.pop(-1) 
            backbone.classifier.append(nn.Linear(1280,1))
        
        elif self.args['backbone'] == 'resnet50':
            backbone = models.resnet50(weights="DEFAULT")
            backbone.fc = nn.Linear(2048,1)
        
        else:
            raise RuntimeError(f'Model {self.args["backbone"]} not supported.')

        self.backbone = backbone
        
        print(torchinfo.summary(self.backbone, (16,3,224,224)))
        # get loss function
        self.loss_fn = torch.nn.BCELoss()
        
        # create experiment folder and save a copy of current config
        subprocess.call(f"mkdir {exp_root}", shell=True)
        with open(f'{exp_root}/config.json','w') as f:
            json.dump(CONFIG,f)
        
        # create logger
        self.std_logger = self.get_logger()
        
        
    def get_logger(self):

        # get logger
        path_log = EXP_ROOT + '/{}/log_train.txt'.format(self.args['exp_name']) 
        logger = logging.getLogger('log')
        logger.setLevel(logging.INFO)
        # this is necessary in Colab, apparently the handler is retained when executing the cell
        logger.handlers.clear()
        # get formatter
        formatter = logging.Formatter('%(asctime)s - %(message)s')

        # get file handler and add it to logger
        # in this way, the logger will write to both the console and the specified file
        fh = logging.FileHandler(path_log, mode='w')
        fh.setFormatter(formatter)
        logger.addHandler(fh)

        # get console handler
        ch = logging.StreamHandler()
        ch.setFormatter(formatter)
        logger.addHandler(ch)

        logger.propagate = False

        return logger
    
    def get_callbacks(self):

        args=self.args
        cpt_callback = ModelCheckpoint(
            dirpath=join(EXP_ROOT,args['exp_name']),
            every_n_epochs=args['save_freq'],
            save_top_k=-1,
            filename='{epoch:04d}'
        )

        bar_callback = TQDMProgressBar(refresh_rate=10)

        return [cpt_callback, bar_callback]

    def get_wb_logger(self):

        args = self.args
        
        wb_logger = WandbLogger(
            save_dir= self.args['exp_name'],
            project='TACV',
            name=self.args['exp_name']
        )

        self.wb_logger = wb_logger

        return [wb_logger]

    def configure_optimizers(self):
        """
        This functions setup the optimizer and the scheduler
        """
        parameters = get_parameters(self.backbone)

        if self.args['optimizer'] == 'sgd':
            optimizer = torch.optim.SGD(
                params=parameters,
                lr=self.args['lr'],
                weight_decay=self.args['w_decay'],
                nesterov=False)
            
        elif self.args['optimizer'] == 'adam':
            optimizer = torch.optim.AdamW(
                params=parameters,
                lr=self.args['lr'],
                weight_decay=self.args['w_decay'])
        else:
            raise RuntimeError('Optimizer type {} not implemented!'.format(self.args['optimizer']))

        self.optimizer = optimizer
        self.args['step'] = self.args['n_epochs']        

        if self.args['scheduler'] == 'step':
            # Learning rate is reduced after 50%, 75% and 90% of samples like in Segdriven original implementation
            part_milestones = [math.ceil(self.args['n_epochs'] * step) for step in [0.5,0.75,0.9]]
            scheduler = torch.optim.lr_scheduler.MultiStepLR(
                optimizer,
                milestones=part_milestones,
                gamma=0.1)
                
        elif self.args['scheduler'] == 'cosine':
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer,
                T_max=self.args['step'] - 1,
                eta_min=0.1 * self.args['lr'])
        
        # dummy scheduler which will never really lower the lr
        if self.args['scheduler'] is None:
            # Learning rate is reduced after 50%, 75% and 90% of samples like in Segdriven original implementation
            part_milestones = [math.ceil(self.args['n_epochs']*1.5)]
            scheduler = torch.optim.lr_scheduler.MultiStepLR(
                optimizer,
                milestones=part_milestones,
                gamma=0.1)
        else:
            raise RuntimeError('Scheduler type {} not implemented!'.format(self.args['scheduler']))
        
        return [self.optimizer], [scheduler]
            
    def structured_log(self, loss, acc, prec, rec, prefix):

        all_metrics = {}
        all_metrics[f'loss/{prefix}'] = loss
        all_metrics[f'accuracy/{prefix}'] = acc
        all_metrics[f'precision/{prefix}'] = prec
        all_metrics[f'recall/{prefix}'] = rec

        self.log_dict(
            all_metrics, 
            on_step=True, 
            on_epoch=True, 
            logger=True,
            sync_dist=True,
            rank_zero_only=True,
            batch_size=self.args['bs']
        )

    def forward_batch(self, batch):

        imgs = batch[0]
        labels = batch[1]
        
        preds = self.forward(imgs)
        
        labels = labels.to(torch.float32)

        preds = self.act(preds)

        return preds, labels

############### ON START FUNCTIONS

    def on_train_start(self):

        self.std_logger.info('Starting training.')
        self.wb_logger.watch(self.backbone, log_freq=100)
        for k, v in self.args.items():
            self.wb_logger.experiment.config.update({k:v})


        return super().on_train_start()
    
    def on_test_start(self):
        
        self.pred_file = EXP_ROOT + '/{}/preds_{}.txt'.format(self.args['exp_name'],self.args['test_split'])

        with open(self.pred_file,'w') as f:
            f.write("id,gt,pred\n")

        self.std_logger.info('Starting testing.')

        return super().on_test_start()

############## STEP FUNCTIONS

    def training_step(self, batch, batch_idx):

        pred, labels = self.forward_batch(batch)

        loss = self.loss_fn(pred, labels)

        acc, prec, rec = compute_metrics(pred, labels)
        
        self.structured_log(loss, acc, prec, rec, prefix='train')

        return loss

    def validation_step(self, batch, batch_idx):

        pred, labels = self.forward_batch(batch)
        
        loss = self.loss_fn(pred, labels)

        acc, prec, rec = compute_metrics(pred, labels)
                
        self.structured_log(loss, acc, prec, rec, prefix='valid')

        return loss    

    def test_step(self, batch, batch_idx):

        with open(self.pred_file,'a') as f:
            
            idxs = batch[2]
            preds, labels = self.forward_batch(batch)

            preds = torch.where(preds>0.5, 1, 0)

            for idx_i, pred_i, label_i in zip(idxs, preds, labels):

                idx_i = int(idx_i.item())
                pred_i = int(pred_i.item())
                label_i = int(label_i.item())
                f.write(f'{idx_i},{label_i},{pred_i}\n')

############# END FUNCTIONS

    def on_test_end(self):

        fp,fn,tp,tn = 0.,0.,0.,0.

        with open(self.pred_file, 'r') as f:
            lines = f.readlines()
        
        # not considering first row (header)
        for line in lines[1:]:
            
            _,gt,pred = line.split(',')
            
            gt, pred = int(gt), int(pred)
            if gt == 0:
                if pred == 0:
                    tn += 1
                else:
                    fp += 1
            else:
                if pred == 0:
                    fn += 1
                else:
                    tp += 1
        
        recall = 100 * tp / (tp + fn)
        precision = 100 * tp / (tp + fp)
        accuracy = 100 * (tp + tn) / (tp + tn + fp + fn)

        self.std_logger.info("Recall: {:2.2f}".format(float(recall)))
        self.std_logger.info("Precision: {:2.2f}".format(float(precision)))
        self.std_logger.info("Accuracy: {:2.2f}".format(float(accuracy)))
    
        return super().on_test_end()
    
############# DATALOADERS

    def get_train_dataloader(self):
        
        args = self.args
        
        if args['apply_fda']:

            # using train of DLC as source and train of our dataset as target
            dataset = DLC2021_FDA(
                root_source=args['train_data_root'],
                root_target=args['test_data_root'],
                split_source=args['train_split'],
                split_target=args['train_split'],
                beta_fda=args['beta_fda']
            )

        else:
            dataset = DLC2021(
                root=args['train_data_root'],
                split=args['train_split']
            )

        self.std_logger.info('TRAIN samples: {}'.format(dataset.__len__()))

        # get dataloader
        dataloader = DataLoader(
            dataset=dataset,
            batch_size=args['bs'],
            num_workers=args['n_workers'],
            shuffle=True,
            drop_last=True
        )

        return dataloader
    
    def get_valid_dataloader(self):

        args = self.args
        
        dataset = DLC2021(
            root=args['train_data_root'],
            split=args['valid_split']
        )

        self.std_logger.info('VALID samples: {}'.format(dataset.__len__()))

        # get dataloader
        dataloader = DataLoader(
            dataset=dataset,
            num_workers=args['n_workers'],
            batch_size=args['bs'],
            shuffle=False,
            drop_last=False
        )

        return dataloader

    def get_test_dataloader(self):

        # test is same as valid actually
        args = self.args
        
        dataset = DLC2021(
            root=args['train_data_root'],
            split=args['test_split']
        )

        self.std_logger.info('TEST samples: {}'.format(dataset.__len__()))

        # get dataloader
        dataloader = DataLoader(
            dataset=dataset,
            num_workers=args['n_workers'],
            batch_size=args['bs'],
            shuffle=False,
            drop_last=False
        )

        return dataloader

    def get_test_custom_dataloader(self):

        # test is same as valid actually
        args = self.args
        
        dataset = DLC2021(
            root=args['test_data_root'],
            split=args['test_split']
        )

        self.std_logger.info('TEST samples: {}'.format(dataset.__len__()))

        # get dataloader
        dataloader = DataLoader(
            dataset=dataset,
            num_workers=args['n_workers'],
            batch_size=args['bs'],
            shuffle=False,
            drop_last=False
        )

        return dataloader

    def forward(self, x):

        feats = self.backbone(x)
        feats = feats.squeeze()
        return feats

# %%
import torch

def compute_metrics(preds, labels):

    preds = torch.where(preds>0.5, 1, 0)

    fp,fn,tp,tn = 0.,0.,0.,0.
    
    for pred, lab in zip(preds, labels):

        pred = int(pred.item())
        gt = int(lab.item())

        if gt == 0:
            if pred == 0:
                tn += 1
            else:
                fp += 1
        else:
            if pred == 0:
                fn += 1
            else:
                tp += 1
    
    recall = tp / (tp + fn) if (tp+fn) > 0 else 0
    precision = tp / (tp + fp) if (tp+fp) > 0 else 0
    accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp+tn+fp+fn) > 0 else 0

    return accuracy, precision, recall

# %%
# standard training
from pytorch_lightning import Trainer

CONFIG = {
    # exp configs
    'exp_name': 'mobilenet_fda_low_1',
    'save_freq' : 5,
    'n_epochs': 10,
    'valid_freq': 1,
    'backbone': 'mobilenet',
    # training configs
    'bs': 32,
    'n_workers': 0,
    'lr': 1e-4,
    'w_decay': 4e-5,
    'optimizer': 'adam',
    'scheduler': None,
    # data configs
    'train_split': 'train',
    'valid_split': 'test',
    'test_split': 'test',
    'train_data_root': 'DLC2021',
    'test_data_root': 'our_data',
    'img_size': (224,224),
    'apply_fda': True,
    'beta_fda': (0.02,0.05),
}

args = CONFIG

system = DocRecDetection(args)

trainer = Trainer(
    logger = system.get_wb_logger(),
    enable_checkpointing=True,
    callbacks=system.get_callbacks(),
    accelerator='gpu',
    log_every_n_steps=1,
    auto_select_gpus=True,
    num_sanity_val_steps=2,
    check_val_every_n_epoch=args['valid_freq'],
    max_epochs=args['n_epochs']
)

train_data = system.get_train_dataloader()
valid_data = system.get_test_custom_dataloader()
test_data = system.get_test_custom_dataloader()

'''

last_epoch=4
trainer.fit(
    system, 
    train_dataloaders=train_data, 
    val_dataloaders=valid_data,
    ckpt_path=EXP_ROOT+'/{}/epoch={:04d}.ckpt'.format(args['exp_name'],last_epoch)
)
'''

last_epoch = args['n_epochs'] - 1
ckpt_path = EXP_ROOT + '/{}/epoch={:04d}.ckpt'.format(args['exp_name'],last_epoch)
trained_model = DocRecDetection.load_from_checkpoint(ckpt_path, config=args)

trainer.test(model=trained_model, dataloaders=test_data)
# Out:
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:396: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# INFO:pytorch_lightning.trainer.connectors.accelerator_connector:Auto select gpus: [0]
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# MobileNetV3                                        [16, 1]                   --
# ├─Sequential: 1-1                                  [16, 576, 7, 7]           --
# │    └─Conv2dNormActivation: 2-1                   [16, 16, 112, 112]        --
# │    │    └─Conv2d: 3-1                            [16, 16, 112, 112]        432
# │    │    └─BatchNorm2d: 3-2                       [16, 16, 112, 112]        32
# │    │    └─Hardswish: 3-3                         [16, 16, 112, 112]        --
# │    └─InvertedResidual: 2-2                       [16, 16, 56, 56]          --
# │    │    └─Sequential: 3-4                        [16, 16, 56, 56]          744
# │    └─InvertedResidual: 2-3                       [16, 24, 28, 28]          --
# │    │    └─Sequential: 3-5                        [16, 24, 28, 28]          3,864
# │    └─InvertedResidual: 2-4                       [16, 24, 28, 28]          --
# │    │    └─Sequential: 3-6                        [16, 24, 28, 28]          5,416
# │    └─InvertedResidual: 2-5                       [16, 40, 14, 14]          --
# │    │    └─Sequential: 3-7                        [16, 40, 14, 14]          13,736
# │    └─InvertedResidual: 2-6                       [16, 40, 14, 14]          --
# │    │    └─Sequential: 3-8                        [16, 40, 14, 14]          57,264
# │    └─InvertedResidual: 2-7                       [16, 40, 14, 14]          --
# │    │    └─Sequential: 3-9                        [16, 40, 14, 14]          57,264
# │    └─InvertedResidual: 2-8                       [16, 48, 14, 14]          --
# │    │    └─Sequential: 3-10                       [16, 48, 14, 14]          21,968
# │    └─InvertedResidual: 2-9                       [16, 48, 14, 14]          --
# │    │    └─Sequential: 3-11                       [16, 48, 14, 14]          29,800
# │    └─InvertedResidual: 2-10                      [16, 96, 7, 7]            --
# │    │    └─Sequential: 3-12                       [16, 96, 7, 7]            91,848
# │    └─InvertedResidual: 2-11                      [16, 96, 7, 7]            --
# │    │    └─Sequential: 3-13                       [16, 96, 7, 7]            294,096
# │    └─InvertedResidual: 2-12                      [16, 96, 7, 7]            --
# │    │    └─Sequential: 3-14                       [16, 96, 7, 7]            294,096
# │    └─Conv2dNormActivation: 2-13                  [16, 576, 7, 7]           --
# │    │    └─Conv2d: 3-15                           [16, 576, 7, 7]           55,296
# │    │    └─BatchNorm2d: 3-16                      [16, 576, 7, 7]           1,152
# │    │    └─Hardswish: 3-17                        [16, 576, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                           [16, 576, 1, 1]           --
# ├─Sequential: 1-3                                  [16, 1]                   --
# │    └─Linear: 2-14                                [16, 1024]                590,848
# │    └─Hardswish: 2-15                             [16, 1024]                --
# │    └─Dropout: 2-16                               [16, 1024]                --
# │    └─Linear: 2-17                                [16, 1]                   1,025
# ====================================================================================================
# Total params: 1,518,881
# Trainable params: 1,518,881
# Non-trainable params: 0
# Total mult-adds (M): 888.06
# ====================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 362.17
# Params size (MB): 6.08
# Estimated Total Size (MB): 377.88
# ====================================================================================================
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# 2022-12-18 15:09:01,202 - TRAIN samples: 31931
# 2022-12-18 15:09:01,232 - TEST samples: 3928
# 2022-12-18 15:09:01,271 - TEST samples: 3928
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# MobileNetV3                                        [16, 1]                   --
# ├─Sequential: 1-1                                  [16, 576, 7, 7]           --
# │    └─Conv2dNormActivation: 2-1                   [16, 16, 112, 112]        --
# │    │    └─Conv2d: 3-1                            [16, 16, 112, 112]        432
# │    │    └─BatchNorm2d: 3-2                       [16, 16, 112, 112]        32
# │    │    └─Hardswish: 3-3                         [16, 16, 112, 112]        --
# │    └─InvertedResidual: 2-2                       [16, 16, 56, 56]          --
# │    │    └─Sequential: 3-4                        [16, 16, 56, 56]          744
# │    └─InvertedResidual: 2-3                       [16, 24, 28, 28]          --
# │    │    └─Sequential: 3-5                        [16, 24, 28, 28]          3,864
# │    └─InvertedResidual: 2-4                       [16, 24, 28, 28]          --
# │    │    └─Sequential: 3-6                        [16, 24, 28, 28]          5,416
# │    └─InvertedResidual: 2-5                       [16, 40, 14, 14]          --
# │    │    └─Sequential: 3-7                        [16, 40, 14, 14]          13,736
# │    └─InvertedResidual: 2-6                       [16, 40, 14, 14]          --
# │    │    └─Sequential: 3-8                        [16, 40, 14, 14]          57,264
# │    └─InvertedResidual: 2-7                       [16, 40, 14, 14]          --
# │    │    └─Sequential: 3-9                        [16, 40, 14, 14]          57,264
# │    └─InvertedResidual: 2-8                       [16, 48, 14, 14]          --
# │    │    └─Sequential: 3-10                       [16, 48, 14, 14]          21,968
# │    └─InvertedResidual: 2-9                       [16, 48, 14, 14]          --
# │    │    └─Sequential: 3-11                       [16, 48, 14, 14]          29,800
# │    └─InvertedResidual: 2-10                      [16, 96, 7, 7]            --
# │    │    └─Sequential: 3-12                       [16, 96, 7, 7]            91,848
# │    └─InvertedResidual: 2-11                      [16, 96, 7, 7]            --
# │    │    └─Sequential: 3-13                       [16, 96, 7, 7]            294,096
# │    └─InvertedResidual: 2-12                      [16, 96, 7, 7]            --
# │    │    └─Sequential: 3-14                       [16, 96, 7, 7]            294,096
# │    └─Conv2dNormActivation: 2-13                  [16, 576, 7, 7]           --
# │    │    └─Conv2d: 3-15                           [16, 576, 7, 7]           55,296
# │    │    └─BatchNorm2d: 3-16                      [16, 576, 7, 7]           1,152
# │    │    └─Hardswish: 3-17                        [16, 576, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                           [16, 576, 1, 1]           --
# ├─Sequential: 1-3                                  [16, 1]                   --
# │    └─Linear: 2-14                                [16, 1024]                590,848
# │    └─Hardswish: 2-15                             [16, 1024]                --
# │    └─Dropout: 2-16                               [16, 1024]                --
# │    └─Linear: 2-17                                [16, 1]                   1,025
# ====================================================================================================
# Total params: 1,518,881
# Trainable params: 1,518,881
# Non-trainable params: 0
# Total mult-adds (M): 888.06
# ====================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 362.17
# Params size (MB): 6.08
# Estimated Total Size (MB): 377.88
# ====================================================================================================
# Testing: 0it [00:00, ?it/s]
# 2022-12-18 15:09:01,761 - Starting testing.
# 2022-12-18 15:09:19,442 - Recall: 31.91
# 2022-12-18 15:09:19,446 - Precision: 78.03
# 2022-12-18 15:09:19,450 - Accuracy: 60.46
# [{}]
